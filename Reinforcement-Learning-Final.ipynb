# %% [markdown]
# # Reinforcement Learning for Portfolio Optimization
# ### Introduction
# For this project, I experiment with reinforcement learning algorithms for portfolio optimization, on behalf of the stakeholder Deutsche Bank. Deutsche Bank believes that reinforcement learning algorithms may represent an opportunity to reduce costs and generate additional return.
#
# The goal of portfolio optimization is to maximize return on investment by balancing capital between a given number of portfolio assets. Reinforcement learning demands a high amount of data, so this model will be rebalancing its portfolio assets once per hour.
#
# Machine learning algorithms have intuitive real-world potential for this sort of rapid trading, as they are able to process data and react much faster than a human. If the algorithm is able to extract any excess return from the market over traditional methods, this would be beneficial to my stakeholder as this represents an opportunity to make money.
#
# First, I construct a reinforcement learning environment and provide the model with possible action choices to take at each timestep.  I will then compare the model's performance to an evenly weighted portfolio of the same assets.
#
# For the purposes of learning and so that I can focus on the coding aspects of the project, I am ignoring several real-world factors that are anticipated to have low effect such as bid-ask spread and transaction fees.
#
# I am designing my environment under the assumption that the algorithm buys and sells each asset immediately before the end of the previous hour.
#
# This is a toy constructed for learning purposes.  There may be errors and it should not be expected to be truly competitive in a real-world scenario.

# %%
# !pip install setuptools==65.5.0;
# !pip install stable-baselines3;
# !pip install sb3-contrib;
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: setuptools==65.5.0 in /usr/local/lib/python3.9/dist-packages (65.5.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: stable-baselines3 in /usr/local/lib/python3.9/dist-packages (1.8.0)
# Requirement already satisfied: torch>=1.11 in /usr/local/lib/python3.9/dist-packages (from stable-baselines3) (2.0.0+cu118)
# Requirement already satisfied: importlib-metadata~=4.13 in /usr/local/lib/python3.9/dist-packages (from stable-baselines3) (4.13.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from stable-baselines3) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from stable-baselines3) (1.22.4)
# Requirement already satisfied: gym==0.21 in /usr/local/lib/python3.9/dist-packages (from stable-baselines3) (0.21.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from stable-baselines3) (1.5.3)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.9/dist-packages (from stable-baselines3) (2.2.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata~=4.13->stable-baselines3) (3.15.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from torch>=1.11->stable-baselines3) (3.1.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch>=1.11->stable-baselines3) (4.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from torch>=1.11->stable-baselines3) (3.11.0)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.9/dist-packages (from torch>=1.11->stable-baselines3) (2.0.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from torch>=1.11->stable-baselines3) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from torch>=1.11->stable-baselines3) (3.1)
# Requirement already satisfied: lit in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.11->stable-baselines3) (16.0.1)
# Requirement already satisfied: cmake in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.11->stable-baselines3) (3.25.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->stable-baselines3) (1.4.4)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->stable-baselines3) (5.12.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->stable-baselines3) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->stable-baselines3) (8.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->stable-baselines3) (4.39.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->stable-baselines3) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib->stable-baselines3) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->stable-baselines3) (23.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->stable-baselines3) (1.0.7)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->stable-baselines3) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->torch>=1.11->stable-baselines3) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->torch>=1.11->stable-baselines3) (1.3.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: sb3-contrib in /usr/local/lib/python3.9/dist-packages (1.8.0)
# Requirement already satisfied: stable-baselines3<2.0,>=1.8.0 in /usr/local/lib/python3.9/dist-packages (from sb3-contrib) (1.8.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from stable-baselines3<2.0,>=1.8.0->sb3-contrib) (3.7.1)
# Requirement already satisfied: importlib-metadata~=4.13 in /usr/local/lib/python3.9/dist-packages (from stable-baselines3<2.0,>=1.8.0->sb3-contrib) (4.13.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from stable-baselines3<2.0,>=1.8.0->sb3-contrib) (1.5.3)
# Requirement already satisfied: torch>=1.11 in /usr/local/lib/python3.9/dist-packages (from stable-baselines3<2.0,>=1.8.0->sb3-contrib) (2.0.0+cu118)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.9/dist-packages (from stable-baselines3<2.0,>=1.8.0->sb3-contrib) (2.2.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from stable-baselines3<2.0,>=1.8.0->sb3-contrib) (1.22.4)
# Requirement already satisfied: gym==0.21 in /usr/local/lib/python3.9/dist-packages (from stable-baselines3<2.0,>=1.8.0->sb3-contrib) (0.21.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata~=4.13->stable-baselines3<2.0,>=1.8.0->sb3-contrib) (3.15.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from torch>=1.11->stable-baselines3<2.0,>=1.8.0->sb3-contrib) (3.1.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from torch>=1.11->stable-baselines3<2.0,>=1.8.0->sb3-contrib) (3.1)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.9/dist-packages (from torch>=1.11->stable-baselines3<2.0,>=1.8.0->sb3-contrib) (2.0.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch>=1.11->stable-baselines3<2.0,>=1.8.0->sb3-contrib) (4.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from torch>=1.11->stable-baselines3<2.0,>=1.8.0->sb3-contrib) (3.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from torch>=1.11->stable-baselines3<2.0,>=1.8.0->sb3-contrib) (1.11.1)
# Requirement already satisfied: lit in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.11->stable-baselines3<2.0,>=1.8.0->sb3-contrib) (16.0.1)
# Requirement already satisfied: cmake in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.11->stable-baselines3<2.0,>=1.8.0->sb3-contrib) (3.25.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->stable-baselines3<2.0,>=1.8.0->sb3-contrib) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->stable-baselines3<2.0,>=1.8.0->sb3-contrib) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->stable-baselines3<2.0,>=1.8.0->sb3-contrib) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->stable-baselines3<2.0,>=1.8.0->sb3-contrib) (8.4.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->stable-baselines3<2.0,>=1.8.0->sb3-contrib) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->stable-baselines3<2.0,>=1.8.0->sb3-contrib) (1.0.7)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib->stable-baselines3<2.0,>=1.8.0->sb3-contrib) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->stable-baselines3<2.0,>=1.8.0->sb3-contrib) (5.12.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->stable-baselines3<2.0,>=1.8.0->sb3-contrib) (23.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->stable-baselines3<2.0,>=1.8.0->sb3-contrib) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3<2.0,>=1.8.0->sb3-contrib) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->torch>=1.11->stable-baselines3<2.0,>=1.8.0->sb3-contrib) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->torch>=1.11->stable-baselines3<2.0,>=1.8.0->sb3-contrib) (1.3.0)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import gym
import random as rand
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from stable_baselines3 import A2C
from stable_baselines3 import PPO
from stable_baselines3.common.env_checker import check_env
import gym
from gym import spaces
import math
from pathlib import Path
import warnings
from sb3_contrib import TRPO
warnings.filterwarnings("ignore")

# %% [markdown]
# # Importing and cleaning data
# ## Data Description
# My machine will be rebalancing a portfolio of six stocks once every hour.
# - AMZN - amzn-1h.csv
# - COST - cost-1h.csv
# - IBM - ibm-1h.csv
# - JNJ - jnj-1h.csv
# - JPM - jpm-1h.csv
# - XOM - xom-1h.csv
#
# Hourly SP500 futures data will be used as a market baseline for portfolio optimization calculations, as a proxy for SP500 hourly index data.
# - SPY- es-1h.csv
#
# US Treasury 1-year yield will be used here to calculate the riskless rate of return for portfolio optimization.
# - USGB - USGB.xslx
#
# The hourly data is sourced from backtestmarket.com.  The treasury yields are sourced from Bloomberg.
#
# ## Data Cleaning
#
# I perform routine data cleaning on the asset DataFrames to enable easy merging.  I create a column for log-normalized daily returns and columns for volatility and variance, each over five days.  I perform similar data cleaning on the treasury yield DataFrame and convert the yearly treasury return to an estimated hourly treasury return, used for riskless rate.
#
# After cleaning, I am left with about 26,000 rows, each representing one hour of market data.

# %%
# Importing data
columnNames=['Date','Open','High','Low','Close','Volume']
AMZN=pd.read_csv('/content/drive/MyDrive/data/1_HR_HIST/amzn-1h.csv',sep=';',names=columnNames)
COST=pd.read_csv('/content/drive/MyDrive/data/1_HR_HIST/cost-1h.csv',sep=';',names=columnNames)
IBM=pd.read_csv('/content/drive/MyDrive/data/1_HR_HIST/ibm-1h.csv',sep=';',names=columnNames)
JNJ=pd.read_csv('/content/drive/MyDrive/data/1_HR_HIST/jnj-1h.csv',sep=';',names=columnNames)
JPM=pd.read_csv('/content/drive/MyDrive/data/1_HR_HIST/jpm-1h.csv',sep=';',names=columnNames)
XOM=pd.read_csv('/content/drive/MyDrive/data/1_HR_HIST/xom-1h.csv',sep=';',names=columnNames)
SPY=pd.read_csv('/content/drive/MyDrive/data/1_HR_HIST/es-1h.csv',sep=';',names=columnNames)
USGB=pd.read_excel('/content/drive/MyDrive/data/portfolio_index/USGB.xlsx')

# %%
# Lists for dataframe loops
assetList=[SPY,AMZN,COST,IBM,JNJ,JPM,XOM]
assetNames=['SPY','AMZN','COST','IBM','JNJ','JPM','XOM']

# %%
# Cleaning the time column and creating a log return column.
# Creating arbitrary empty columns for volatility and variance to be added later.
# Appending asset names to column names for merging later.
newDFs=[]
for i in range(7):
  asset=assetList[i]
  assetName=assetNames[i]
  asset['Hour']=asset['Date']
  asset['Date']=asset.index
  asset['Year']=asset['Date'].str[-4:].astype(int)
  asset=asset.loc[asset['Year']>=2007]
  asset['Date']=asset[['Date','Hour']].agg('/'.join,axis=1)
  asset['Date']=asset['Date'].str[:-6]
  asset=asset.reset_index()
  asset[assetName+'-Close']=asset['Close']
  asset[assetName+'-LogRet']=np.log(asset['Close']/asset['Close'].shift())
  asset[assetName+'-Vol5H']=asset[assetName+'-LogRet']
  asset[assetName+'-Variance']=asset[assetName+'-LogRet']
  asset=asset[['Date',assetName+'-Close',assetName+'-LogRet',assetName+'-Vol5H',assetName+'-Variance']]
  newDFs.append(asset)

# Overwriting individual asset DFs with cleaned DFs.
SPY,AMZN,COST,IBM,JNJ,JPM,XOM=newDFs[0],newDFs[1],newDFs[2],newDFs[3],newDFs[4],newDFs[5],newDFs[6]
assetList=[SPY,AMZN,COST,IBM,JNJ,JPM,XOM]

# %%
# Function to calculate volatility and variance.  
def realizedVol(series):
  vol=series.std()*np.sqrt(len(series))
  var=vol**2
  return vol,var

# Adding volatility and variance to DFs. 
# Comment out if allDF import is used. 
#newDFsDFs=[]
#for i in range(7):
#  asset=assetList[i]
#  assetName=assetNames[i]
#  for i in range(6,len(asset)):
#    series=asset.iloc[i-5:i,-3]
#    var,vol=realizedVol(series.values)
#    asset[assetName+'-Variance'].iloc[i]=var
#    asset[assetName+'-Vol5H'].iloc[i]=vol
#  newDFsDFs.append(asset)


# Merging new DFs into one DF.
# Comment out if allDF import is used.

#allDF=newDFsDFs[0]
#for d in newDFsDFs[1:]:
#  allDF=pd.merge(allDF,d,on='Date')
#for asset in assetNames:
#  allDF[asset+'-PrevClose']=allDF[asset+'-Close'].shift(1)
#allDF
# Creating a backup of this DF.
#from pathlib import Path
filepath = Path('/content/drive/MyDrive/data/1_HR_HIST/allDFbase.csv')  
#filepath.parent.mkdir(parents=True, exist_ok=True)  
#allDF.to_csv(filepath)  

allDF=pd.read_csv(filepath)
allDF=allDF.drop('Unnamed: 0',axis=1)

# %%
# Rearranging order of DF columns. 
newColOrder=['Date','SPY-Close','AMZN-Close', 'COST-Close', 'IBM-Close',
             'JNJ-Close','JPM-Close','XOM-Close',
             'SPY-PrevClose','AMZN-PrevClose', 'COST-PrevClose', 'IBM-PrevClose',
             'JNJ-PrevClose','JPM-PrevClose','XOM-PrevClose',
             'SPY-LogRet','AMZN-LogRet', 'COST-LogRet','IBM-LogRet',
             'JNJ-LogRet','JPM-LogRet','XOM-LogRet',
             'SPY-Vol5H','AMZN-Vol5H', 'COST-Vol5H', 'IBM-Vol5H',   
             'JNJ-Vol5H', 'JPM-Vol5H', 'XOM-Vol5H','SPY-Variance']
allDF=allDF[newColOrder]
allDF
# Out:
#                 Date  SPY-Close  AMZN-Close  COST-Close  IBM-Close  JNJ-Close  \
# 0      02/04/2007/09    1431.75      1.9919     39.3522    57.8397    38.5080
# 1      02/04/2007/10    1431.00      1.9869     39.2385    57.9092    38.4557
# 2      02/04/2007/11    1430.75      2.0003     39.2763    58.2723    38.4731
# 3      02/04/2007/12    1430.75      2.0013     39.2289    58.2416    38.4296
# 4      02/04/2007/13    1432.00      2.0033     39.3619    58.2183    38.4731
# ...              ...        ...         ...         ...        ...        ...
# 28151  06/04/2023/10    4121.25    100.6000    481.5600   130.8800   165.0100
# 28152  06/04/2023/11    4126.50    101.3950    485.0200   130.6800   165.5600
# 28153  06/04/2023/12    4129.00    101.3050    486.8500   131.0000   165.7100
# 28154  06/04/2023/13    4129.75    101.7100    485.4000   130.5348   166.0000
# 28155  06/04/2023/14    4132.50    101.9599    483.9400   130.6050   165.5300
#
#        JPM-Close  XOM-Close  SPY-PrevClose  AMZN-PrevClose  ...  JPM-LogRet  \
# 0        31.8013    40.5853            NaN             NaN  ...   -0.006472
# 1        31.7149    40.6348        1431.75          1.9919  ...   -0.002721
# 2        31.6806    40.7475        1431.00          1.9869  ...   -0.001082
# 3        31.7840    40.8739        1430.75          2.0003  ...    0.003259
# 4        31.7495    40.8529        1430.75          2.0013  ...   -0.001086
# ...          ...        ...            ...             ...  ...         ...
# 28151   127.6700   116.3400        4104.25        100.2739  ...    0.002667
# 28152   127.6600   116.3800        4121.25        100.6000  ...   -0.000078
# 28153   127.6971   116.2400        4126.50        101.3950  ...    0.000291
# 28154   127.5950   116.3800        4129.00        101.3050  ...   -0.000800
# 28155   127.7100   115.5400        4129.75        101.7100  ...    0.000901
#
#        XOM-LogRet     SPY-Vol5H  AMZN-Vol5H  COST-Vol5H  IBM-Vol5H  JNJ-Vol5H  \
# 0        0.003465  1.500145e-06    0.000096    0.000055   0.000046   0.000016
# 1        0.001219  1.060327e-06    0.000106    0.000063   0.000032   0.000015
# 2        0.002770  1.194605e-06    0.000029    0.000068   0.000029   0.000011
# 3        0.003097  7.555869e-07    0.000051    0.000068   0.000051   0.000011
# 4       -0.000514  2.072797e-07    0.000051    0.000047   0.000042   0.000008
# ...           ...           ...         ...         ...        ...        ...
# 28151   -0.004588  1.684663e-05    0.000072    0.001267   0.000041   0.000004
# 28152    0.000344  3.343329e-05    0.000095    0.001458   0.000042   0.000068
# 28153   -0.001204  3.300630e-05    0.000151    0.001551   0.000027   0.000069
# 28154    0.001204  2.065036e-05    0.000151    0.001600   0.000042   0.000068
# 28155   -0.007244  1.004966e-05    0.000149    0.001591   0.000043   0.000055
#
#        JPM-Vol5H  XOM-Vol5H  SPY-Variance
# 0       0.000142   0.000085      0.001225
# 1       0.000103   0.000039      0.001030
# 2       0.000100   0.000034      0.001093
# 3       0.000057   0.000033      0.000869
# 4       0.000049   0.000029      0.000455
# ...          ...        ...           ...
# 28151   0.000016   0.000057      0.004104
# 28152   0.000013   0.000076      0.005782
# 28153   0.000013   0.000058      0.005745
# 28154   0.000010   0.000052      0.004544
# 28155   0.000011   0.000020      0.003170
#
# [28156 rows x 30 columns]

# %%
# Cleaning USGB data and converting yearly rate to hourly rate.
USGB2=USGB[6:]
USGB2=USGB2.iloc[::-1]
USGB2=USGB2.rename(columns={'Security':'Date'})
USGB2['HourlyRate']=((USGB2['USGB360D Index                                                  ']/100)).astype('float64')
USGB2['HourlyRate']=100*((np.log(1+USGB2['HourlyRate'])/255/7))
USGB2.index=USGB2['Date']
USGB2
# Out:
#                            Date  \
# Date
# 2008-08-14  2008-08-14 00:00:00
# 2008-08-15  2008-08-15 00:00:00
# 2008-08-18  2008-08-18 00:00:00
# 2008-08-19  2008-08-19 00:00:00
# 2008-08-20  2008-08-20 00:00:00
# ...                         ...
# 2023-03-20  2023-03-20 00:00:00
# 2023-03-21  2023-03-21 00:00:00
# 2023-03-22  2023-03-22 00:00:00
# 2023-03-23  2023-03-23 00:00:00
# 2023-03-24  2023-03-24 00:00:00
#
#            USGB360D Index                                                    \
# Date
# 2008-08-14                                            2.03504
# 2008-08-15                                            2.03527
# 2008-08-18                                            1.99433
# 2008-08-19                                            1.95365
# 2008-08-20                                            1.93467
# ...                                                       ...
# 2023-03-20                                            4.21378
# 2023-03-21                                            4.27056
# 2023-03-22                                            4.18976
# 2023-03-23                                            4.08525
# 2023-03-24                                            4.09364
#
#             HourlyRate
# Date
# 2008-08-14    0.001129
# 2008-08-15    0.001129
# 2008-08-18    0.001106
# 2008-08-19    0.001084
# 2008-08-20    0.001073
# ...                ...
# 2023-03-20    0.002312
# 2023-03-21    0.002343
# 2023-03-22    0.002299
# 2023-03-23    0.002243
# 2023-03-24    0.002248
#
# [3794 rows x 3 columns]

# %%
# Creating a temporary DF for normalizing the USGB date to match asset hourly dates.
# Using this resultant 'Date' column to merge with allDF.
df=pd.DataFrame()
df.index=pd.date_range('2008-08-14','2023-03-24',freq='H')
df['Date']=df.index.date
# Filling missing rate values, since it merges from daily to hourly.
df['Rate']=USGB2['HourlyRate']
df=df.fillna(method='ffill', downcast='infer')
# Normalizing the Date column.
df['Date']=df['Date'].astype(str)
df['Year']=df['Date'].str[:4]
df['x']=df.index.astype(str)
df['Hour']=df['x'].str[11:13]
df['Day']=df['Date'].str[-2:]
df['Month']=df['Date'].str[5:7]
df['Date']=df['Day']+'/'+df['Month']+'/'+df['Year']+'/'+df['Hour']
# Resetting the index and merging.
df=df.reset_index()
df=df[['Date','Rate']]
allDF=pd.merge(allDF,df,on='Date')
allDF
# Out:
#                 Date  SPY-Close  AMZN-Close  COST-Close  IBM-Close  JNJ-Close  \
# 0      14/08/2008/09    1291.50      4.3169     49.5870    78.6554    47.1187
# 1      14/08/2008/10    1293.75      4.3653     49.7769    79.8999    47.1972
# 2      14/08/2008/11    1298.00      4.3748     50.0715    80.2554    47.3711
# 3      14/08/2008/12    1295.25      4.4197     50.4893    80.2865    47.4932
# 4      14/08/2008/13    1291.25      4.4017     50.1473    80.1551    47.2841
# ...              ...        ...         ...         ...        ...        ...
# 25676  23/03/2023/11    4014.00    100.4499    492.1100   124.5890   150.8500
# 25677  23/03/2023/12    3994.00    100.1850    490.7250   124.3914   151.4850
# 25678  23/03/2023/13    3968.00     99.3642    490.9214   123.9800   151.2800
# 25679  23/03/2023/14    3975.75     98.3400    486.0600   123.2200   150.7750
# 25680  23/03/2023/15    3987.50     98.7100    487.7600   123.3300   151.0400
#
#        JPM-Close  XOM-Close  SPY-PrevClose  AMZN-PrevClose  ...  XOM-LogRet  \
# 0        25.9249    42.7034        1284.75          4.3304  ...   -0.007224
# 1        26.2780    42.9851        1291.50          4.3169  ...    0.006575
# 2        26.3729    42.8653        1293.75          4.3653  ...   -0.002791
# 3        26.6312    42.5205        1298.00          4.3748  ...   -0.008076
# 4        26.4505    42.7176        1295.25          4.4197  ...    0.004625
# ...          ...        ...            ...             ...  ...         ...
# 25676   127.4100   105.7500        4027.00        100.8270  ...   -0.001134
# 25677   127.1520   104.6500        4014.00        100.4499  ...   -0.010456
# 25678   126.2888   103.8700        3994.00        100.1850  ...   -0.007481
# 25679   125.6637   102.9500        3968.00         99.3642  ...   -0.008897
# 25680   125.8522   103.3100        3975.75         98.3400  ...    0.003491
#
#        SPY-Vol5H  AMZN-Vol5H  COST-Vol5H  IBM-Vol5H  JNJ-Vol5H  JPM-Vol5H  \
# 0       0.000083    0.001014    0.000303   0.000135   0.000027   0.000736
# 1       0.000133    0.000576    0.000217   0.000152   0.000018   0.000656
# 2       0.000133    0.000623    0.000223   0.000353   0.000018   0.000721
# 3       0.000137    0.000606    0.000217   0.000349   0.000024   0.000713
# 4       0.000044    0.000370    0.000196   0.000334   0.000026   0.000702
# ...          ...         ...         ...        ...        ...        ...
# 25676   0.000040    0.000544    0.000189   0.000279   0.000075   0.000465
# 25677   0.000063    0.000529    0.000189   0.000282   0.000071   0.000462
# 25678   0.000093    0.000525    0.000193   0.000279   0.000100   0.000455
# 25679   0.000101    0.000313    0.000061   0.000105   0.000022   0.000223
# 25680   0.000045    0.000224    0.000141   0.000126   0.000032   0.000023
#
#        XOM-Vol5H  SPY-Variance      Rate
# 0       0.000081      0.009091  0.001129
# 1       0.000116      0.011517  0.001129
# 2       0.000161      0.011553  0.001129
# 3       0.000138      0.011696  0.001129
# 4       0.000152      0.006661  0.001129
# ...          ...           ...       ...
# 25676   0.000332      0.006322  0.002243
# 25677   0.000332      0.007922  0.002243
# 25678   0.000398      0.009642  0.002243
# 25679   0.000235      0.010036  0.002243
# 25680   0.000166      0.006707  0.002243
#
# [25681 rows x 31 columns]

# %% [markdown]
# # Performing portfolio optimization calculations
# I calculate asset betas and use that to derive a value for expected rate of return.  I then experiment with a few naive portfolio optimization equations including the Sharpe ratio, maximum diversification, and minimum variance.
#
# I chose not to use minimum variance in the final model as it gave inconsistent weights.
#
# Since it takes a long time to iterate over approximately 26,000 rows for each of these methods, I save the portfolio weights generated by each method as an Excel sheet.

# %%
# Creating a beta dataframe to perform expected return calculations with. 
betaDF=allDF[['SPY-LogRet','AMZN-LogRet', 'COST-LogRet','IBM-LogRet',
             'JNJ-LogRet','JPM-LogRet','XOM-LogRet','SPY-Variance',
              'AMZN-Vol5H','COST-Vol5H','IBM-Vol5H','JNJ-Vol5H','XOM-Vol5H',
              'JPM-Vol5H','Rate']]
etfList=['AMZN','COST','IBM','JNJ','JPM','XOM']
for etf in etfList:
  dfCov=betaDF[[etf+'-LogRet','SPY-LogRet']].rolling(5).cov().unstack()
  betaDF[etf+'-cov']=dfCov['SPY-LogRet'][etf+'-LogRet'];
for etf in etfList:
  betaDF[etf+'-beta']=100*betaDF[etf+'-cov']/betaDF['SPY-Variance']
betaDF
# Out:
#        SPY-LogRet  AMZN-LogRet  COST-LogRet  IBM-LogRet  JNJ-LogRet  \
# 0        0.006993    -0.003122    -0.003822   -0.005100    0.000743
# 1        0.001741     0.011149     0.003822    0.015698    0.001665
# 2        0.003280     0.002174     0.005901    0.004439    0.003678
# 3       -0.002121     0.010211     0.008309    0.000387    0.002574
# 4       -0.003093    -0.004081    -0.006797   -0.001638   -0.004412
# ...           ...          ...          ...         ...         ...
# 25676   -0.003233    -0.003747    -0.001401   -0.000169   -0.000994
# 25677   -0.004995    -0.002641    -0.002818   -0.001587    0.004201
# 25678   -0.006531    -0.008227     0.000400   -0.003313   -0.001354
# 25679    0.001951    -0.010361    -0.009952   -0.006149   -0.003344
# 25680    0.002951     0.003755     0.003491    0.000892    0.001756
#
#        JPM-LogRet  XOM-LogRet  SPY-Variance  AMZN-Vol5H  COST-Vol5H  ...  \
# 0        0.010025   -0.007224      0.009091    0.001014    0.000303  ...
# 1        0.013528    0.006575      0.011517    0.000576    0.000217  ...
# 2        0.003605   -0.002791      0.011553    0.000623    0.000223  ...
# 3        0.009746   -0.008076      0.011696    0.000606    0.000217  ...
# 4       -0.006808    0.004625      0.006661    0.000370    0.000196  ...
# ...           ...         ...           ...         ...         ...  ...
# 25676   -0.002295   -0.001134      0.006322    0.000544    0.000189  ...
# 25677   -0.002027   -0.010456      0.007922    0.000529    0.000189  ...
# 25678   -0.006812   -0.007481      0.009642    0.000525    0.000193  ...
# 25679   -0.004962   -0.008897      0.010036    0.000313    0.000061  ...
# 25680    0.001499    0.003491      0.006707    0.000224    0.000141  ...
#
#             IBM-cov   JNJ-cov   JPM-cov   XOM-cov  AMZN-beta  COST-beta  \
# 0               NaN       NaN       NaN       NaN        NaN        NaN
# 1               NaN       NaN       NaN       NaN        NaN        NaN
# 2               NaN       NaN       NaN       NaN        NaN        NaN
# 3               NaN       NaN       NaN       NaN        NaN        NaN
# 4     -2.071598e-06  0.000006  0.000016 -0.000009  -0.099616  -0.027798
# ...             ...       ...       ...       ...        ...        ...
# 25676 -1.518700e-05 -0.000013  0.000011  0.000004   0.465311   0.111307
# 25677 -9.912670e-06 -0.000009  0.000021  0.000020   0.261070   0.092620
# 25678 -8.692654e-07 -0.000003  0.000036  0.000033   0.417848   0.128835
# 25679  7.762302e-07 -0.000005  0.000002  0.000005   0.016011  -0.073258
# 25680  9.732975e-08 -0.000002  0.000007  0.000012   0.104618  -0.049899
#
#        IBM-beta  JNJ-beta  JPM-beta  XOM-beta
# 0           NaN       NaN       NaN       NaN
# 1           NaN       NaN       NaN       NaN
# 2           NaN       NaN       NaN       NaN
# 3           NaN       NaN       NaN       NaN
# 4     -0.031102  0.084706  0.243727 -0.135229
# ...         ...       ...       ...       ...
# 25676 -0.240222 -0.199515  0.171957  0.059764
# 25677 -0.125130 -0.110122  0.262836  0.249051
# 25678 -0.009015 -0.035983  0.377256  0.344244
# 25679  0.007735 -0.045092  0.016198  0.048987
# 25680  0.001451 -0.036323  0.104368  0.184303
#
# [25681 rows x 27 columns]

# %%
# Creating individual DFs for variable categories across stocks, for 
# easy access later. 
priceDF=allDF[['AMZN-Close', 'COST-Close', 'IBM-Close','JNJ-Close', 'JPM-Close', 'XOM-Close']]
logReturnsDF=allDF[['AMZN-LogRet','COST-LogRet', 'IBM-LogRet', 'JNJ-LogRet', 'JPM-LogRet', 'XOM-LogRet']]
realizedVolDF=allDF[['AMZN-Vol5H', 'COST-Vol5H', 'IBM-Vol5H', 'JNJ-Vol5H','JPM-Vol5H', 'XOM-Vol5H']]

# %%
# Creating an expected return DF and performing ER calculations using beta. 
expReturns=allDF[['SPY-Close','IBM-Close']]
expReturns['SPY']=allDF['SPY-Close'].pct_change(periods=5)
expReturns['AMZN-ExR']=betaDF['Rate']+betaDF['AMZN-beta']*(expReturns['SPY']-betaDF['Rate'])
expReturns['COST-ExR']=betaDF['Rate']+betaDF['COST-beta']*(expReturns['SPY']-betaDF['Rate'])
expReturns['IBM-ExR']=betaDF['Rate']+betaDF['IBM-beta']*(expReturns['SPY']-betaDF['Rate'])
expReturns['JNJ-ExR']=betaDF['Rate']+betaDF['JNJ-beta']*(expReturns['SPY']-betaDF['Rate'])
expReturns['JPM-ExR']=betaDF['Rate']+betaDF['JPM-beta']*(expReturns['SPY']-betaDF['Rate'])
expReturns['XOM-ExR']=betaDF['Rate']+betaDF['XOM-beta']*(expReturns['SPY']-betaDF['Rate'])
# Adding volatility to ER DF.
volList=['AMZN-Vol5H','COST-Vol5H','IBM-Vol5H','JNJ-Vol5H',
         'JPM-Vol5H','XOM-Vol5H']
for column in volList:
  expReturns[column]=allDF[column]
# Dropping unneeded columns.
expReturns=expReturns.drop(columns=['SPY-Close','IBM-Close'],axis=1)
expReturns
# Out:
#             SPY  AMZN-ExR  COST-ExR   IBM-ExR   JNJ-ExR   JPM-ExR   XOM-ExR  \
# 0           NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1           NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2           NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3           NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4           NaN       NaN       NaN       NaN       NaN       NaN       NaN
# ...         ...       ...       ...       ...       ...       ...       ...
# 25676 -0.004958 -0.001108  0.001442  0.003973  0.003680  0.001005  0.001813
# 25677  0.006299  0.003302  0.002619  0.001736  0.001797  0.003309  0.003253
# 25678 -0.000944  0.000911  0.001833  0.002272  0.002358  0.001041  0.001146
# 25679 -0.013645  0.001989  0.003407  0.002120  0.002960  0.001986  0.001465
# 25680 -0.009809  0.000982  0.002845  0.002226  0.002681  0.000985  0.000022
#
#        AMZN-Vol5H  COST-Vol5H  IBM-Vol5H  JNJ-Vol5H  JPM-Vol5H  XOM-Vol5H
# 0        0.001014    0.000303   0.000135   0.000027   0.000736   0.000081
# 1        0.000576    0.000217   0.000152   0.000018   0.000656   0.000116
# 2        0.000623    0.000223   0.000353   0.000018   0.000721   0.000161
# 3        0.000606    0.000217   0.000349   0.000024   0.000713   0.000138
# 4        0.000370    0.000196   0.000334   0.000026   0.000702   0.000152
# ...           ...         ...        ...        ...        ...        ...
# 25676    0.000544    0.000189   0.000279   0.000075   0.000465   0.000332
# 25677    0.000529    0.000189   0.000282   0.000071   0.000462   0.000332
# 25678    0.000525    0.000193   0.000279   0.000100   0.000455   0.000398
# 25679    0.000313    0.000061   0.000105   0.000022   0.000223   0.000235
# 25680    0.000224    0.000141   0.000126   0.000032   0.000023   0.000166
#
# [25681 rows x 13 columns]

# %%
# Cleaner versions of the above DFs.
expReturnsDF=expReturns[['AMZN-ExR', 'COST-ExR', 'IBM-ExR', 'JNJ-ExR', 'JPM-ExR','XOM-ExR']]
for column in ['AMZN-ExR', 'COST-ExR', 'IBM-ExR', 'JNJ-ExR', 'JPM-ExR','XOM-ExR']:
  expReturnsDF[column]=expReturnsDF[column]
for column in ['AMZN-LogRet','COST-LogRet', 'IBM-LogRet', 'JNJ-LogRet', 'JPM-LogRet', 'XOM-LogRet']:
  logReturnsDF[column]=logReturnsDF[column]
# Dropping the first five values of all DFs.  
# This should remove all NaNs while ensuring orders and lengths don't become mismatched.
logReturnsDF=logReturnsDF[5:]
priceDF=priceDF[5:]
realizedVolDF=realizedVolDF[5:]
allDF=allDF[5:]
expReturnsDF=expReturnsDF[5:]
# Verifying that DF lengths match.
len(allDF),len(logReturnsDF),len(priceDF),len(realizedVolDF),len(expReturnsDF)
# Out:
# (25676, 25676, 25676, 25676, 25676)

# %%
# Maximum diversification portfolio weights
# Creates 100 possible portfolios where 
# Portfolio-v is volatility and 
# Portfolio-r is summed asset volatility
def testPortfolioWeightsMaxDivers(i):
  portfolioReturns=[]
  portfolioVolatilities=[]
  portfolioWeights=[]
  portfolioTestCount=100
  for i in range(portfolioTestCount-1):
    weights=np.random.random(6)
    weights=weights/np.sum(weights)
    portfolioWeights.append(weights)
    portfolioReturn=np.mean(realizedVolDF.iloc[i-5:i,:])
    returns=np.dot(weights,portfolioReturn)
    portfolioReturns.append(returns)
    covMatrix=logReturnsDF.iloc[i-5:i,:].cov()
    P_ret=returns
    P_vol=np.sqrt(np.dot(weights.T,np.dot(covMatrix,weights)))
    portfolioVolatilities.append(P_vol)
  dfWeights=pd.DataFrame(portfolioWeights,columns=['AMZN-w','COST-w','IBM-w','JNJ-w','JPM-w','XOM-w'])
  rf=betaDF['Rate'].iloc[i]
  df=pd.DataFrame()
  df['Portfolio-r']=portfolioReturns
  df['Portfolio-v']=portfolioVolatilities
  df['Portfolio-s']=(df['Portfolio-r']-rf)/df['Portfolio-v']
  df=pd.concat([df,dfWeights],axis=1)
  return df.dropna()
np.seterr(all='ignore')
testPortfolioWeightsMaxDivers(0)
# Out:
#     Portfolio-r  Portfolio-v  Portfolio-s    AMZN-w    COST-w     IBM-w  \
# 5      0.000239     0.003316    -0.256898  0.125129  0.147564  0.150188
# 6      0.000251     0.001889    -0.444287  0.183782  0.061208  0.253610
# 7      0.000190     0.001124    -0.801374  0.060004  0.171675  0.232668
# 8      0.000164     0.001151    -0.804943  0.104832  0.104029  0.181340
# 9      0.000201     0.003385    -0.262988  0.104537  0.282668  0.000768
# ..          ...          ...          ...       ...       ...       ...
# 94     0.000247     0.005366    -0.157204  0.214816  0.077858  0.313039
# 95     0.000215     0.007010    -0.124952  0.122366  0.209362  0.071568
# 96     0.000198     0.004793    -0.186185  0.029908  0.312608  0.236575
# 97     0.000195     0.005210    -0.171847  0.309035  0.110004  0.242944
# 98     0.000246     0.004019    -0.210078  0.001269  0.124103  0.254444
#
#        JNJ-w     JPM-w     XOM-w
# 5   0.222992  0.235283  0.118844
# 6   0.158291  0.243928  0.099181
# 7   0.144056  0.139892  0.251705
# 8   0.353770  0.164946  0.091083
# 9   0.293831  0.308039  0.010156
# ..       ...       ...       ...
# 94  0.015116  0.023610  0.355561
# 95  0.028402  0.110932  0.457369
# 96  0.250201  0.103734  0.066975
# 97  0.081907  0.124834  0.131276
# 98  0.154004  0.283998  0.182182
#
# [94 rows x 9 columns]

# %%
# Sharpe ratio portfolio weights
# Creates 100 possible portfolios where 
# Portfolio-v is volatility and 
# Portfolio-r is summed asset expected return.
def testPortfolioWeights(i):
  portfolioReturns=[]
  portfolioVolatilities=[]
  portfolioWeights=[]
  portfolioTestCount=100
  calcVol=realizedVolDF.iloc[i-5:i,:]
  for i in range(portfolioTestCount-1):
    weights=np.random.random(6)
    weights=weights/np.sum(weights)
    portfolioWeights.append(weights)
    portfolioReturn=expReturnsDF.iloc[i,:]
    returns=np.dot(weights,portfolioReturn)
    portfolioReturns.append(returns)
    covMatrix=logReturnsDF.iloc[i-5:i,:].cov()
    P_ret=returns
    P_vol=np.sqrt(np.dot(weights.T,np.dot(covMatrix,weights)))
    portfolioVolatilities.append(P_vol)
  dfWeights=pd.DataFrame(portfolioWeights,columns=['ARKK-w','GLD-w','R2K-w','QQQ-w','XLE-w','BND-w'])
  rf=betaDF['Rate'].iloc[i]
  df=pd.DataFrame()
  df['Portfolio-r']=portfolioReturns
  df['Portfolio-v']=portfolioVolatilities
  df['Portfolio-s']=(df['Portfolio-r']-rf)/df['Portfolio-v']
  df=pd.concat([df,dfWeights],axis=1)
  return df.dropna()
np.seterr(all='ignore')
testPortfolioWeights(10)
# Out:
#     Portfolio-r  Portfolio-v  Portfolio-s    ARKK-w     GLD-w     R2K-w  \
# 5      0.001333     0.004904     0.049405  0.197433  0.195691  0.046529
# 6      0.001189     0.004043     0.024401  0.143192  0.078948  0.201095
# 7      0.001072     0.001811    -0.010247  0.166229  0.065608  0.134276
# 8      0.001086     0.002002    -0.002208  0.274198  0.022252  0.279188
# 9      0.001117     0.001537     0.016860  0.245383  0.240927  0.211660
# ..          ...          ...          ...       ...       ...       ...
# 94    -0.001125     0.005409    -0.409651  0.209821  0.000627  0.257794
# 95    -0.001799     0.006212    -0.465130  0.067157  0.164068  0.030463
# 96    -0.004960     0.005787    -1.045527  0.169555  0.212242  0.138103
# 97    -0.002331     0.008346    -0.409926  0.041737  0.054647  0.188300
# 98     0.000295     0.003958    -0.200990  0.164605  0.208162  0.088713
#
#        QQQ-w     XLE-w     BND-w
# 5   0.208969  0.316461  0.034915
# 6   0.014169  0.016422  0.546174
# 7   0.096415  0.209004  0.328468
# 8   0.000783  0.308836  0.114743
# 9   0.008308  0.104517  0.189205
# ..       ...       ...       ...
# 94  0.066741  0.256141  0.208875
# 95  0.241131  0.123466  0.373714
# 96  0.056604  0.138371  0.285125
# 97  0.111809  0.559763  0.043743
# 98  0.108322  0.165853  0.264345
#
# [94 rows x 9 columns]

# %%
# Finds best maximimum diversification weights for a timestep.
# Generates possible portfolio combinations and chooses the 
# portfolio with the lowest ratio, Portfolio-s.
def findMaxDiversAndWeights(i):
  df=testPortfolioWeightsMaxDivers(i)
  best=df.loc[df['Portfolio-s'].idxmin()]
  P_ret,P_vol=best[0],best[1]
  weights=best[3:].tolist()
  sharpe=P_ret/P_vol
  return sharpe,weights,P_ret
findMaxDiversAndWeights(5)
# Out:
# (0.11854445745905372,
#  [0.09370384031910899,
#   0.3277425358508357,
#   0.06074751856684276,
#   0.29208958031193016,
#   0.0026482081026238118,
#   0.2230683168486586],
#  0.00014085251526035604)

# %%
# Finds best Sharpe weights for a timestep. 
# Generates possible portfolio combinations and chooses the 
# portfolio with the highest ratio, Portfolio-s.
def findSharpeAndWeights(i):
  df=testPortfolioWeights(i)
  best=df.loc[df['Portfolio-s'].idxmax()]
  P_ret,P_vol=best[0],best[1]
  weights=best[3:].tolist()
  sharpe=P_ret/P_vol
  return sharpe,weights,P_ret
findSharpeAndWeights(5)
# Out:
# (0.4403028617569048,
#  [0.06477982010095328,
#   0.17000564735314336,
#   0.3053343800353738,
#   0.2215731597768196,
#   0.05878516513939258,
#   0.17952182759431742],
#  0.0036211599652859598)

# %%
# Finds best minimum variance weights for a timestep. 
# Generates possible portfolio combinations and chooses the
# portfolio with the lowest volatility, Portfolio-v.
def findMarkAndWeights(i):
  df=testPortfolioWeights(i)
  best=df.loc[df['Portfolio-v'].idxmin()]
  P_ret,P_vol=best[0],best[1]
  weights=best[3:].tolist()
  sharpe=P_ret/P_vol
  return sharpe,weights,P_ret
findMarkAndWeights(5)
# Out:
# (0.31584358774727284,
#  [0.14588270145570767,
#   0.22877345172756264,
#   0.25321225634276984,
#   0.139501889536388,
#   0.14318277410549649,
#   0.08944692683207525],
#  0.0002712290597794378)

# %%
# Iterates through DF and finds maxDiv weights for all timesteps. 
# Saves as a CSV.
# Comment out if loading from csv file.

#maxDiversList=[]
#for i in range(len(expReturnsDF)):
#  sharpe,maxDivWeights,P_ret=findMaxDiversAndWeights(i)
#  maxDiversList.append(maxDivWeights)
#  if i%100==0:
#    print(i)
#maxDivDF=pd.DataFrame(maxDiversList)
filepath = Path('/content/drive/MyDrive/data/1_HR_HIST/maxDivDFbase.csv')  
#filepath.parent.mkdir(parents=True, exist_ok=True)  
#maxDivDF.to_csv(filepath) 

maxDivDF=pd.read_csv('/content/drive/MyDrive/data/1_HR_HIST/maxDivDFbase.csv')
maxDivDF=maxDivDF.drop('Unnamed: 0',axis=1)
maxDivDF
# Out:
#               0         1         2         3         4         5
# 0      0.248731  0.194059  0.086249  0.368877  0.042667  0.059418
# 1      0.172350  0.135341  0.334991  0.038925  0.047634  0.270759
# 2      0.264852  0.051676  0.274467  0.221439  0.052790  0.134776
# 3      0.336555  0.183570  0.072846  0.189648  0.001701  0.215681
# 4      0.345794  0.278438  0.132455  0.149171  0.038776  0.055366
# ...         ...       ...       ...       ...       ...       ...
# 25671  0.117287  0.122051  0.165484  0.263360  0.054333  0.277486
# 25672  0.090041  0.215857  0.241372  0.171895  0.052265  0.228570
# 25673  0.181441  0.141003  0.030837  0.344010  0.110999  0.191710
# 25674  0.155087  0.340009  0.109987  0.332755  0.042260  0.019902
# 25675  0.116603  0.051313  0.231330  0.213831  0.104442  0.282481
#
# [25676 rows x 6 columns]

# %%
# Iterates through a DF and finds best Sharpe weights for all timesteps.
# Saves as a CSV.
# Comment out if loading from csv file.

#sharpeList=[]
#for i in range(len(expReturnsDF)):
#  sharpe,sharpeWeights,P_ret=findSharpeAndWeights(i)
#  sharpeList.append(sharpeWeights)
#  if i%100==0:
#    print(i)
#sharpeDF=pd.DataFrame(sharpeList)
#filepath = Path('/content/drive/MyDrive/data/1_HR_HIST/sharpeDFbase.csv')  
#filepath.parent.mkdir(parents=True, exist_ok=True)  
#sharpeDF.to_csv(filepath) 
sharpeDF=pd.read_csv('/content/drive/MyDrive/data/1_HR_HIST/sharpeDFbase3.csv')
sharpeDF=sharpeDF.drop('Unnamed: 0',axis=1)
sharpeDF
# Out:
#               0         1         2         3         4         5
# 0      0.272398  0.043547  0.050844  0.180191  0.151820  0.301201
# 1      0.190645  0.068733  0.220573  0.049993  0.155849  0.314207
# 2      0.164103  0.424062  0.123546  0.039510  0.205638  0.043143
# 3      0.264084  0.083208  0.222926  0.117368  0.175258  0.137156
# 4      0.259681  0.230506  0.137568  0.183654  0.046434  0.142157
# ...         ...       ...       ...       ...       ...       ...
# 25671  0.179975  0.244190  0.054616  0.041729  0.092517  0.386973
# 25672  0.211732  0.196250  0.182911  0.169769  0.149972  0.089365
# 25673  0.371890  0.144795  0.071690  0.000687  0.088252  0.322685
# 25674  0.078754  0.207314  0.226894  0.081608  0.119493  0.285937
# 25675  0.027574  0.040995  0.260120  0.315767  0.178754  0.176790
#
# [25676 rows x 6 columns]

# %%
# Iterates through a DF and finds best minimum variance weights for a timestep.
# Saves as a CSV.
# Comment out if loading from csv file.

#markList=[]
#for i in range(len(expReturnsDF)):
#  mark,markWeights,P_ret=findMarkAndWeights(i)
#  markList.append(markWeights)
#  if i%100==0:
#    print(i)
#markDF=pd.DataFrame(markList)
filepath = Path('/content/drive/MyDrive/data/1_HR_HIST/markDFbaseLOWRISK.csv')
#filepath.parent.mkdir(parents=True, exist_ok=True)  
#markDF.to_csv(filepath)
 
markDF=pd.read_csv(filepath)
markDF=markDF.drop('Unnamed: 0',axis=1)
markDF
# Out:
#               0         1         2         3         4         5
# 0      0.224567  0.144007  0.229205  0.309387  0.019723  0.073111
# 1      0.199000  0.069814  0.218596  0.058646  0.176145  0.277799
# 2      0.044039  0.239683  0.106389  0.235406  0.095858  0.278625
# 3      0.255954  0.250864  0.133761  0.050440  0.202183  0.106799
# 4      0.129574  0.144860  0.071779  0.458131  0.039896  0.155758
# ...         ...       ...       ...       ...       ...       ...
# 25671  0.210694  0.150036  0.141741  0.213254  0.144350  0.139924
# 25672  0.021058  0.237733  0.634917  0.019120  0.031827  0.055345
# 25673  0.233000  0.161718  0.095684  0.103046  0.262822  0.143730
# 25674  0.248432  0.299195  0.113901  0.116754  0.221230  0.000490
# 25675  0.175514  0.088846  0.130838  0.226587  0.139391  0.238824
#
# [25676 rows x 6 columns]

# %% [markdown]
# # Reinforcement learning
#
# First, I create a train-test split using the above data.  I then construct the RL trading environment.  The model will choose between different optimization strategies as its action choices.
#
# I include all market data included in allDF as the observation space.  Including other variables such as asset betas is not considered necessary as these values are derived from the allDF values.  The state space is chosen to consist of the variables the machine can affect.
#
# During crude early experimentation, I gave the model action options such as 'wait and do nothing for a timestep', 'select random weights', and 'sell all assets and convert to cash for a round'.
#
# These performed poorly enough that the model never chose them, so I will experiment with portfolio methods instead.
#
# A balanced portfolio, with 1/6th of its funds in each asset constant across the timespace, will be used as a naive baseline.

# %%
#allDF=allDF.drop('Date',axis=1)
all_train,all_test,price_train,price_test,log_return_train,log_return_test,vol_train,vol_test,sharpe_train,sharpe_test,mark_train,mark_test,maxDiv_train,maxDiv_test=train_test_split(allDF,priceDF,logReturnsDF,realizedVolDF,sharpeDF,markDF,maxDivDF,shuffle=False)
all_test #2019-07-30 to 2023-03-23
# Out:
#        SPY-Close  AMZN-Close  COST-Close  IBM-Close  JNJ-Close  JPM-Close  \
# 19262    3013.00     94.4390    271.1850   126.6289   120.1903   104.6488
# 19263    3014.50     94.8474    271.3890   126.5655   120.2814   104.9299
# 19264    3014.75     94.7252    271.4762   126.5023   120.3545   104.9844
# 19265    3015.25     94.7044    271.2628   126.4262   120.4822   104.8210
# 19266    3013.00     94.3663    270.3795   126.4223   119.8282   104.5671
# ...          ...         ...         ...        ...        ...        ...
# 25676    4014.00    100.4499    492.1100   124.5890   150.8500   127.4100
# 25677    3994.00    100.1850    490.7250   124.3914   151.4850   127.1520
# 25678    3968.00     99.3642    490.9214   123.9800   151.2800   126.2888
# 25679    3975.75     98.3400    486.0600   123.2200   150.7750   125.6637
# 25680    3987.50     98.7100    487.7600   123.3300   151.0400   125.8522
#
#        XOM-Close  SPY-PrevClose  AMZN-PrevClose  COST-PrevClose  ...  \
# 19262    58.0424        3010.25         94.4092        271.6021  ...
# 19263    58.2277        3013.00         94.4390        271.1850  ...
# 19264    58.2124        3014.50         94.8474        271.3890  ...
# 19265    58.2048        3014.75         94.7252        271.4762  ...
# 19266    58.0578        3015.25         94.7044        271.2628  ...
# ...          ...            ...             ...             ...  ...
# 25676   105.7500        4027.00        100.8270        492.8000  ...
# 25677   104.6500        4014.00        100.4499        492.1100  ...
# 25678   103.8700        3994.00        100.1850        490.7250  ...
# 25679   102.9500        3968.00         99.3642        490.9214  ...
# 25680   103.3100        3975.75         98.3400        486.0600  ...
#
#        XOM-LogRet  SPY-Vol5H  AMZN-Vol5H    COST-Vol5H  IBM-Vol5H  JNJ-Vol5H  \
# 19262    0.000600   0.000004    0.000026  8.313567e-07   0.000088   0.000141
# 19263    0.003187   0.000003    0.000020  1.641682e-06   0.000090   0.000127
# 19264   -0.000263   0.000001    0.000052  2.857516e-06   0.000089   0.000130
# 19265   -0.000131   0.000001    0.000038  3.234645e-06   0.000004   0.000015
# 19266   -0.002529   0.000001    0.000019  3.336555e-06   0.000002   0.000005
# ...           ...        ...         ...           ...        ...        ...
# 25676   -0.001134   0.000040    0.000544  1.885183e-04   0.000279   0.000075
# 25677   -0.010456   0.000063    0.000529  1.892782e-04   0.000282   0.000071
# 25678   -0.007481   0.000093    0.000525  1.932731e-04   0.000279   0.000100
# 25679   -0.008897   0.000101    0.000313  6.101149e-05   0.000105   0.000022
# 25680    0.003491   0.000045    0.000224  1.411801e-04   0.000126   0.000032
#
#        JPM-Vol5H  XOM-Vol5H  SPY-Variance      Rate
# 19262   0.000015   0.000036      0.001878  0.001067
# 19263   0.000011   0.000037      0.001659  0.001067
# 19264   0.000021   0.000045      0.001147  0.001067
# 19265   0.000008   0.000045      0.001122  0.001067
# 19266   0.000010   0.000010      0.001220  0.001068
# ...          ...        ...           ...       ...
# 25676   0.000465   0.000332      0.006322  0.002243
# 25677   0.000462   0.000332      0.007922  0.002243
# 25678   0.000455   0.000398      0.009642  0.002243
# 25679   0.000223   0.000235      0.010036  0.002243
# 25680   0.000023   0.000166      0.006707  0.002243
#
# [6419 rows x 30 columns]

# %%
class train_env(gym.Env):
  """Custom Environment that follows gym interface"""
  #metadata = {'render.modes': ['human']}
  def __init__(self,all,price,realizedVol,sharpe,mark):
    #super(train_env, self).__init__()
    self.all_train=all
    self.price_train=price
    self.vol_train=realizedVol
    self.sharpe_train=sharpe
    self.mark_train=mark

    self.netWorthHistory=[100]
    self.unweightedWorthHistory=[100]
    self.sharpeNWWorthHistory=[100]
    self.markNWWorthHistory=[100]

    self.actionHistory=[]
    self.action1ct=0
    self.action2ct=0
    self.action3ct=0

    self.day=5
    self.observations=np.array(self.all_train.iloc[self.day-1],dtype=np.float32)
    self.action_space = spaces.Discrete(2) #0, 1, 2

    self.observation_space=spaces.Box(low=-np.inf,high=np.inf,shape=[30])
    self.reward=0
    self.net_worth=100
    self.even_net_worth=100
    self.sharpe_net_worth=100
    self.mark_net_worth=100

    self.weights=[1/6 for i in range(6)]
    self.even_weights=[1/6 for i in range(6)]
    self.sharpeWeights=self.sharpe_train.iloc[self.day].values.tolist()
    self.markWeights=self.mark_train.iloc[self.day].values.tolist()

    self.volatility=self.vol_train.iloc[self.day-1].values.tolist()

    self.previous_prices=self.price_train.iloc[self.day-1].values.tolist()
    self.current_prices=self.price_train.iloc[self.day].values.tolist()

    self.previous_shares=self.weightsToShares(self.weights,self.net_worth)
    self.shares=self.weightsToShares(self.weights,self.net_worth)
    self.even_shares=self.weightsToShares(self.even_weights,self.net_worth)

    self.previous_asset_values=[self.previous_shares[i]*self.current_prices[i] for i in range(6)]
    self.asset_values=[self.shares[i]*self.current_prices[i] for i in range(6)]

    self.sharpeShares=self.weightsToShares(self.sharpeWeights,self.sharpe_net_worth)
    self.current_sharpe_assets=[self.current_prices[i]*self.sharpeShares[i] for i in range(6)]
    self.sharpe_net_worth=np.sum(self.current_sharpe_assets)
    self.sharpeNWWorthHistory.append(self.sharpe_net_worth)

    self.markShares=self.weightsToShares(self.markWeights,self.mark_net_worth)
    self.current_mark_assets=[self.current_prices[i]*self.markShares[i] for i in range(6)]
    self.mark_net_worth=np.sum(self.current_mark_assets)
    self.markNWWorthHistory.append(self.mark_net_worth)

    self.state=[self.net_worth]+self.shares+self.previous_prices+self.weights+self.volatility
    self.action=self.get_action()
    #self.net_worth=0,self.shares=[1:8],self.asset_values=[8:15],self.weights=[15:22]
    self.reset()
    self.step(self.action)

  def reset(self):
    # Reset the state of the environment to an initial state
    self.netWorthHistory=[100]
    self.unweightedWorthHistory=[100]
    self.sharpeNWWorthHistory=[100]
    self.markNWWorthHistory=[100]

    self.actionHistory=[]
    self.action1ct=0
    self.action2ct=0
    self.action3ct=0

    self.day=5
    self.observations=np.array(self.all_train.iloc[self.day-1],dtype=np.float32)
    self.action_space = spaces.Discrete(2) 

    self.observation_space=spaces.Box(low=-np.inf,high=np.inf,shape=[30])
    self.reward=0
    self.net_worth=100
    self.even_net_worth=100
    self.sharpe_net_worth=100
    self.mark_net_worth=100

    self.weights=[1/6 for i in range(6)]
    self.even_weights=[1/6 for i in range(6)]

    self.sharpeWeights=self.sharpe_train.iloc[self.day].values.tolist()
    self.markWeights=self.mark_train.iloc[self.day].values.tolist()
    self.volatility=self.vol_train.iloc[self.day-1].values.tolist()

    self.previous_prices=self.price_train.iloc[self.day-1].values.tolist()
    self.current_prices=self.price_train.iloc[self.day].values.tolist()

    self.previous_asset_values=[self.previous_shares[i]*self.current_prices[i] for i in range(6)]
    self.asset_values=[self.shares[i]*self.current_prices[i] for i in range(6)]

    self.sharpeShares=self.weightsToShares(self.sharpeWeights,self.sharpe_net_worth)
    self.current_sharpe_assets=[self.current_prices[i]*self.sharpeShares[i] for i in range(6)]
    self.sharpe_net_worth=np.sum(self.current_sharpe_assets)
    self.sharpeNWWorthHistory.append(self.sharpe_net_worth)

    self.markShares=self.weightsToShares(self.markWeights,self.mark_net_worth)
    self.current_mark_assets=[self.current_prices[i]*self.markShares[i] for i in range(6)]
    self.mark_net_worth=np.sum(self.current_mark_assets)
    self.markNWWorthHistory.append(self.mark_net_worth)


    self.state=[self.net_worth]+self.shares+self.previous_prices+self.weights+self.volatility
    self.action=self.get_action()
    return self.nextObservations()

  def step(self,action):
    self.done=(self.day>=len(self.all_train)-1)
    if self.done:
      return self.state,self.reward,self.done, {'info':1}
    else:
      self.take_action(action)
      self.day+=1

      self.volatility=self.vol_train.iloc[self.day-1].values.tolist()
      self.previous_prices=self.price_train.iloc[self.day-1].values.tolist()
      self.current_prices=self.price_train.iloc[self.day].values.tolist()
  
      self.sharpeWeights=self.sharpe_train.iloc[self.day].values.tolist()
      self.sharpeShares=self.weightsToShares(self.sharpeWeights,self.sharpe_net_worth)
      self.current_sharpe_assets=[self.current_prices[i]*self.sharpeShares[i] for i in range(6)]
      self.sharpe_net_worth=np.sum(self.current_sharpe_assets)
      self.sharpeNWWorthHistory.append(self.sharpe_net_worth)

      self.markWeights=self.mark_train.iloc[self.day].values.tolist()
      self.markShares=self.weightsToShares(self.markWeights,self.mark_net_worth)
      self.current_mark_assets=[self.current_prices[i]*self.markShares[i] for i in range(6)]
      self.mark_net_worth=np.sum(self.current_mark_assets)
      self.markNWWorthHistory.append(self.mark_net_worth)

      self.even_shares=self.weightsToShares([1/6 for i in range(6)],self.even_net_worth)
      self.current_even_assets=[self.current_prices[i]*self.even_shares[i] for i in range(6)]
      self.even_net_worth=np.sum(self.current_even_assets)
      self.unweightedWorthHistory.append(self.even_net_worth)


      self.state=[self.net_worth]+self.shares+self.previous_prices+self.weights+self.volatility
      self.action=self.get_action()
      return self.nextObservations(), self.reward, self.done, {'info':1}

  def nextObservations(self):
    day=self.day
    frame=np.array(self.all_train.iloc[day-1],dtype=np.float32)
    return frame

  def weightsToShares(self,weights1,net_worth):
    weightsValue=[net_worth*weights1[i] for i in range(6)]
    shares=[weightsValue[i]/self.previous_prices[i] for i in range(6)]
    return shares 

  def shareChangeToReward(self,newShares,action_type):

    self.previous_asset_values=np.sum([newShares[i]*self.previous_prices[i] for i in range(6)])
    self.shares=newShares
    self.asset_values=[self.shares[i]*self.current_prices[i] for i in range(6)]
    self.market_diff=np.sum(self.current_prices)/np.sum(self.previous_prices)
    self.portfolio_diff=(np.sum(self.asset_values))/np.sum(self.previous_asset_values)

    self.reward=self.portfolio_diff-self.market_diff
    self.net_worth=np.sum(self.asset_values)

    self.netWorthHistory.append(np.sum(self.asset_values))
    return self.reward

  def take_action(self,action):
    action_type=action
    self.actionHistory.append(action)
    if action_type==1:
      self.sharpeWeights=self.sharpe_train.iloc[self.day].values.tolist()
      self.shares=self.weightsToShares(self.sharpeWeights,self.net_worth)
      self.shareChangeToReward(self.shares,action_type)
      self.weights=self.sharpeWeights
      self.action1ct+=1
      return self.reward

    else:
      self.markWeights=self.mark_train.iloc[self.day].values.tolist()
      self.shares=self.weightsToShares(self.markWeights,self.net_worth)
      self.shareChangeToReward(self.shares,action_type)
      self.weights=self.markWeights
      self.action2ct+=1
      return self.reward

  def get_action(self):
    pass

# %% [markdown]
# # PPO model
# ## Iterating over 50,000 training steps
# This is equivalent to approximately two loops of the training data.
#
# Due to randomness in data and model choices, there is expected to be some divergence between outcomes each time the code is run.

# %%
env=train_env(all_train,price_train,vol_train,sharpe_train,maxDiv_train)
env.reset()
#env.step(env.action_space.sample())
PPOmodel = PPO('MlpPolicy', env, verbose=1)
PPOmodel.learn(total_timesteps=50000)
print(env.reward,env.net_worth)
print(env.action1ct,env.action2ct,env.action3ct)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# -----------------------------
# | time/              |      |
# |    fps             | 716  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 553         |
# |    iterations           | 2           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.017139561 |
# |    clip_fraction        | 0.0423      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.684      |
# |    explained_variance   | -0.242      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000293   |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00198    |
# |    value_loss           | 0.000754    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 543         |
# |    iterations           | 3           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009074416 |
# |    clip_fraction        | 0.00859     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | -1.6        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0013     |
# |    n_updates            | 20          |
# |    policy_gradient_loss | 0.00025     |
# |    value_loss           | 0.000149    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 529         |
# |    iterations           | 4           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.003111659 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.693      |
# |    explained_variance   | -0.141      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0017      |
# |    n_updates            | 30          |
# |    policy_gradient_loss | 0.000214    |
# |    value_loss           | 0.000106    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 518         |
# |    iterations           | 5           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008599112 |
# |    clip_fraction        | 0.00937     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.691      |
# |    explained_variance   | -0.000285   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0355     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.000286   |
# |    value_loss           | 4.79e-05    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 516        |
# |    iterations           | 6          |
# |    time_elapsed         | 23         |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.01195698 |
# |    clip_fraction        | 0.0175     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.675     |
# |    explained_variance   | -7.15e-07  |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0178    |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.00107   |
# |    value_loss           | 4.32e-05   |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 515        |
# |    iterations           | 7          |
# |    time_elapsed         | 27         |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.01023538 |
# |    clip_fraction        | 0.0555     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.683     |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.02       |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.00357   |
# |    value_loss           | 5.8e-05    |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 506          |
# |    iterations           | 8            |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0041769193 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.692       |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0126      |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.000168    |
# |    value_loss           | 2.51e-05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 502          |
# |    iterations           | 9            |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0041823885 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.692       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00264      |
# |    n_updates            | 80           |
# |    policy_gradient_loss | 6.25e-05     |
# |    value_loss           | 2.16e-05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.93e+04    |
# |    ep_rew_mean          | 0.647       |
# | time/                   |             |
# |    fps                  | 503         |
# |    iterations           | 10          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.008249456 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.692      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0209     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.000495   |
# |    value_loss           | 2.65e-05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.93e+04     |
# |    ep_rew_mean          | 0.647        |
# | time/                   |              |
# |    fps                  | 503          |
# |    iterations           | 11           |
# |    time_elapsed         | 44           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0012048145 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.691       |
# |    explained_variance   | -0.0014      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00419     |
# |    n_updates            | 100          |
# |    policy_gradient_loss | 9.53e-05     |
# |    value_loss           | 9.13e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.93e+04     |
# |    ep_rew_mean          | 0.647        |
# | time/                   |              |
# |    fps                  | 505          |
# |    iterations           | 12           |
# |    time_elapsed         | 48           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0015082277 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.691       |
# |    explained_variance   | 0.000108     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00478      |
# |    n_updates            | 110          |
# |    policy_gradient_loss | 9.44e-06     |
# |    value_loss           | 2.55e-05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.93e+04      |
# |    ep_rew_mean          | 0.647         |
# | time/                   |               |
# |    fps                  | 500           |
# |    iterations           | 13            |
# |    time_elapsed         | 53            |
# |    total_timesteps      | 26624         |
# | train/                  |               |
# |    approx_kl            | 1.5357888e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | -0.00913      |
# |    learning_rate        | 0.0003        |
# |    loss                 | -7.41e-05     |
# |    n_updates            | 120           |
# |    policy_gradient_loss | 0.000174      |
# |    value_loss           | 2.69e-05      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.93e+04    |
# |    ep_rew_mean          | 0.647       |
# | time/                   |             |
# |    fps                  | 497         |
# |    iterations           | 14          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.017975066 |
# |    clip_fraction        | 0.0187      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.682      |
# |    explained_variance   | 2.53e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0045      |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00191    |
# |    value_loss           | 2.08e-05    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.93e+04   |
# |    ep_rew_mean          | 0.647      |
# | time/                   |            |
# |    fps                  | 496        |
# |    iterations           | 15         |
# |    time_elapsed         | 61         |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.01125177 |
# |    clip_fraction        | 0.00713    |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.644     |
# |    explained_variance   | -9.54e-07  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00701    |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.000526  |
# |    value_loss           | 2.13e-05   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.93e+04   |
# |    ep_rew_mean          | 0.647      |
# | time/                   |            |
# |    fps                  | 491        |
# |    iterations           | 16         |
# |    time_elapsed         | 66         |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.00800744 |
# |    clip_fraction        | 0.0462     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.655     |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0181    |
# |    n_updates            | 150        |
# |    policy_gradient_loss | -0.00289   |
# |    value_loss           | 1.45e-05   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.93e+04    |
# |    ep_rew_mean          | 0.647       |
# | time/                   |             |
# |    fps                  | 489         |
# |    iterations           | 17          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.011456055 |
# |    clip_fraction        | 0.0357      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.626      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0175     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00238    |
# |    value_loss           | 3.03e-05    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.93e+04      |
# |    ep_rew_mean          | 0.647         |
# | time/                   |               |
# |    fps                  | 488           |
# |    iterations           | 18            |
# |    time_elapsed         | 75            |
# |    total_timesteps      | 36864         |
# | train/                  |               |
# |    approx_kl            | 3.3216755e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.616        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.000495     |
# |    n_updates            | 170           |
# |    policy_gradient_loss | 0.000158      |
# |    value_loss           | 1.4e-05       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.93e+04      |
# |    ep_rew_mean          | 0.515         |
# | time/                   |               |
# |    fps                  | 489           |
# |    iterations           | 19            |
# |    time_elapsed         | 79            |
# |    total_timesteps      | 38912         |
# | train/                  |               |
# |    approx_kl            | 7.7228746e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.63         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.000353     |
# |    n_updates            | 180           |
# |    policy_gradient_loss | 0.000228      |
# |    value_loss           | 1.48e-05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.93e+04     |
# |    ep_rew_mean          | 0.515        |
# | time/                   |              |
# |    fps                  | 484          |
# |    iterations           | 20           |
# |    time_elapsed         | 84           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0056684464 |
# |    clip_fraction        | 0.0121       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.585       |
# |    explained_variance   | 0.000258     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00467     |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.000769    |
# |    value_loss           | 4.54e-05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.93e+04    |
# |    ep_rew_mean          | 0.515       |
# | time/                   |             |
# |    fps                  | 476         |
# |    iterations           | 21          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.006195835 |
# |    clip_fraction        | 0.0183      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.612      |
# |    explained_variance   | -6.96e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.003       |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00129    |
# |    value_loss           | 5.99e-05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.93e+04     |
# |    ep_rew_mean          | 0.515        |
# | time/                   |              |
# |    fps                  | 475          |
# |    iterations           | 22           |
# |    time_elapsed         | 94           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0055480804 |
# |    clip_fraction        | 0.013        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.651       |
# |    explained_variance   | 2.25e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0224       |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.000772    |
# |    value_loss           | 1.77e-05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.93e+04    |
# |    ep_rew_mean          | 0.515       |
# | time/                   |             |
# |    fps                  | 474         |
# |    iterations           | 23          |
# |    time_elapsed         | 99          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.011620076 |
# |    clip_fraction        | 0.0309      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.631      |
# |    explained_variance   | 0.000832    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0167      |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00211    |
# |    value_loss           | 2.39e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.93e+04    |
# |    ep_rew_mean          | 0.515       |
# | time/                   |             |
# |    fps                  | 471         |
# |    iterations           | 24          |
# |    time_elapsed         | 104         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.007510946 |
# |    clip_fraction        | 0.0252      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.648      |
# |    explained_variance   | -1.31e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0159      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0015     |
# |    value_loss           | 2.16e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.93e+04    |
# |    ep_rew_mean          | 0.515       |
# | time/                   |             |
# |    fps                  | 464         |
# |    iterations           | 25          |
# |    time_elapsed         | 110         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.009891658 |
# |    clip_fraction        | 0.0646      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.677      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00937    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0038     |
# |    value_loss           | 2.11e-05    |
# -----------------------------------------
# 0.0009944243323289914 263.01579200689577
# 8328 4368 0

# %%
test_env=train_env(all_test,price_test,vol_test,sharpe_test,maxDiv_test)
PPOrewardList=[]
PPOunweightedRewardList=[]
PPOsharpeRewardList=[]
PPOmarkRewardList=[]
test_env.reset()
obvs=test_env.reset()
done=False
while done == False:
  action,_states=PPOmodel.predict(obvs)
  obvs,rewards,done,info=test_env.step(action)
  #print('NW',test_env.net_worth)
  PPOrewardList.append(test_env.net_worth)
  PPOunweightedRewardList.append(test_env.even_net_worth)
  PPOsharpeRewardList.append(test_env.sharpe_net_worth)
  PPOmarkRewardList.append(test_env.mark_net_worth)

# %%
plt.figure(figsize=(10,10))
plt.plot(PPOrewardList,linewidth=3,color='black', label='Robot Return')
plt.plot(PPOunweightedRewardList,linewidth=2,color='orange',label='Baseline Portfolio')
plt.plot(PPOsharpeRewardList,linewidth=1,color='blue', label='Sharpe')
plt.plot(PPOmarkRewardList,linewidth=1,color='purple',label='Max Diverse')
plt.legend()
env.portfolio_diff
# Out:
# 1.0020077670363583

# %%
test_env=train_env(all_test,price_test,vol_test,sharpe_test,maxDiv_test)
episodes = 1
PPOrewardList2=[]
PPOunweightedRewardList2=[]
PPOsharpeRewardList2=[]
PPOmarkRewardList2=[]
test_env.reset()
obvs=test_env.reset()
done=False
while done == False:
  action,_states=PPOmodel.predict(obvs)
  obvs,rewards,done,info=test_env.step(action)
  PPOrewardList2.append(test_env.net_worth)
  PPOunweightedRewardList2.append(test_env.even_net_worth)
  PPOsharpeRewardList2.append(test_env.sharpe_net_worth)
  PPOmarkRewardList2.append(test_env.mark_net_worth)

# %%
plt.figure(figsize=(10,10))
plt.plot(PPOrewardList2,linewidth=3,color='black', label='Robot Return')
plt.plot(PPOunweightedRewardList2,linewidth=3, color='orange',label='Baseline Portfolio')
plt.plot(PPOsharpeRewardList2,linewidth=1,color='blue',label='Sharpe',linestyle='dashed')
plt.plot(PPOmarkRewardList2,linewidth=1,color='purple',label='Max Diverse',linestyle='dashed')
plt.title('PPO')
plt.legend()
print(PPOrewardList2[-1]/PPOunweightedRewardList2[-1])
print(PPOrewardList2[-1])
# Out:
# 1.1059728858586857
# 159.07466195538973

# %%
test_env=train_env(all_test,price_test,vol_test,sharpe_test,maxDiv_test)
episodes = 1
PPOrewardList3=[]
PPOunweightedRewardList3=[]
PPOsharpeRewardList3=[]
PPOmarkRewardList3=[]
test_env.reset()
obvs=test_env.reset()
done=False
while done == False:
  action,_states=PPOmodel.predict(obvs)
  obvs,rewards,done,info=test_env.step(action)
  PPOrewardList3.append(test_env.net_worth)
  PPOunweightedRewardList3.append(test_env.even_net_worth)
  PPOsharpeRewardList3.append(test_env.sharpe_net_worth)
  PPOmarkRewardList3.append(test_env.mark_net_worth)

# %%
plt.figure(figsize=(10,10))
plt.plot(PPOrewardList3,linewidth=3,color='black', label='Robot Return')
plt.plot(PPOunweightedRewardList3,linewidth=3, color='orange',label='Baseline Portfolio')
plt.plot(PPOsharpeRewardList3,linewidth=1,color='blue',label='Sharpe',linestyle='dashed')
plt.plot(PPOmarkRewardList3,linewidth=1,color='purple',label='Max Diverse',linestyle='dashed')
plt.title('PPO')
plt.legend()
print(PPOrewardList3[-1]/PPOunweightedRewardList3[-1])
print(PPOrewardList3[-1])
# Out:
# 1.2060704288810746
# 173.4719252359347

# %%
test_env=train_env(all_test,price_test,vol_test,sharpe_test,maxDiv_test)
episodes = 1
PPOrewardList4=[]
PPOunweightedRewardList4=[]
PPOsharpeRewardList4=[]
PPOmarkRewardList4=[]
test_env.reset()
obvs=test_env.reset()
done=False
while done == False:
  action,_states=PPOmodel.predict(obvs)
  obvs,rewards,done,info=test_env.step(action)
  PPOrewardList4.append(test_env.net_worth)
  PPOunweightedRewardList4.append(test_env.even_net_worth)
  PPOsharpeRewardList4.append(test_env.sharpe_net_worth)
  PPOmarkRewardList4.append(test_env.mark_net_worth)

# %%
plt.figure(figsize=(10,10))
plt.plot(PPOrewardList4,linewidth=3,color='black', label='Robot Return')
plt.plot(PPOunweightedRewardList4,linewidth=3, color='orange',label='Baseline Portfolio')
plt.plot(PPOsharpeRewardList4,linewidth=1,color='blue',label='Sharpe',linestyle='dashed')
plt.plot(PPOmarkRewardList4,linewidth=1,color='purple',label='Max Diverse',linestyle='dashed')
plt.title('PPO')
plt.legend()
print(PPOrewardList4[-1]/PPOunweightedRewardList4[-1])
print(PPOrewardList4[-1])
# Out:
# 1.2691217654819502
# 182.54074616623492

# %%
test_env=train_env(all_test,price_test,vol_test,sharpe_test,maxDiv_test)
episodes = 1
PPOrewardList5=[]
PPOunweightedRewardList5=[]
PPOsharpeRewardList5=[]
PPOmarkRewardList5=[]
test_env.reset()
obvs=test_env.reset()
done=False
while done == False:
  action,_states=PPOmodel.predict(obvs)
  obvs,rewards,done,info=test_env.step(action)
  PPOrewardList5.append(test_env.net_worth)
  PPOunweightedRewardList5.append(test_env.even_net_worth)
  PPOsharpeRewardList5.append(test_env.sharpe_net_worth)
  PPOmarkRewardList5.append(test_env.mark_net_worth)

# %%
plt.figure(figsize=(10,10))
plt.plot(PPOrewardList5,linewidth=3,color='black', label='Robot Return')
plt.plot(PPOunweightedRewardList5,linewidth=3, color='orange',label='Baseline Portfolio')
plt.plot(PPOsharpeRewardList5,linewidth=1,color='blue',label='Sharpe',linestyle='dashed')
plt.plot(PPOmarkRewardList5,linewidth=1,color='purple',label='Max Diverse',linestyle='dashed')
plt.title('PPO')
plt.legend()
print(PPOrewardList5[-1]/PPOunweightedRewardList5[-1])
print(PPOrewardList5[-1])
# Out:
# 1.2426051617145304
# 178.72680114602554

# %% [markdown]
# # A2C model - 50,000 timesteps
#
# The actor-critic model is expected to be more cautious than PPO due to its adversarial nature.

# %%
env=train_env(all_train,price_train,vol_train,sharpe_train,maxDiv_train)
env.reset()
A2Cmodel = A2C('MlpPolicy', env, verbose=1)
A2Cmodel.learn(total_timesteps=50000)
print(env.reward,env.net_worth)
print(env.action1ct,env.action2ct,env.action3ct)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ------------------------------------
# | time/                 |          |
# |    fps                | 404      |
# |    iterations         | 100      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -0.684   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | -0.00791 |
# |    value_loss         | 0.000153 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 392       |
# |    iterations         | 200       |
# |    time_elapsed       | 2         |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -0.639    |
# |    explained_variance | -4.77e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199       |
# |    policy_loss        | -0.00808  |
# |    value_loss         | 7.74e-05  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 371      |
# |    iterations         | 300      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -0.691   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | 0.00208  |
# |    value_loss         | 1.3e-05  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 355      |
# |    iterations         | 400      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -0.693   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | 6.06e-05 |
# |    value_loss         | 1.19e-06 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 364      |
# |    iterations         | 500      |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -0.665   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | -0.00124 |
# |    value_loss         | 5.6e-06  |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 372       |
# |    iterations         | 600       |
# |    time_elapsed       | 8         |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -0.64     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 599       |
# |    policy_loss        | -0.000506 |
# |    value_loss         | 6e-06     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 378       |
# |    iterations         | 700       |
# |    time_elapsed       | 9         |
# |    total_timesteps    | 3500      |
# | train/                |           |
# |    entropy_loss       | -0.64     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 699       |
# |    policy_loss        | -0.000632 |
# |    value_loss         | 1.39e-06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 380       |
# |    iterations         | 800       |
# |    time_elapsed       | 10        |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -0.683    |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 799       |
# |    policy_loss        | 0.000936  |
# |    value_loss         | 7.39e-06  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 383      |
# |    iterations         | 900      |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -0.681   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | 0.00489  |
# |    value_loss         | 5.29e-05 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 373       |
# |    iterations         | 1000      |
# |    time_elapsed       | 13        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -0.692    |
# |    explained_variance | -0.000798 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 999       |
# |    policy_loss        | 0.00068   |
# |    value_loss         | 1.25e-06  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 359      |
# |    iterations         | 1100     |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -0.685   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | -0.00329 |
# |    value_loss         | 2.74e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 356      |
# |    iterations         | 1200     |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -0.661   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | 0.00108  |
# |    value_loss         | 3.85e-06 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 350      |
# |    iterations         | 1300     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -0.645   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | 0.00375  |
# |    value_loss         | 3.57e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 350      |
# |    iterations         | 1400     |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 7000     |
# | train/                |          |
# |    entropy_loss       | -0.665   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1399     |
# |    policy_loss        | -3.2e-05 |
# |    value_loss         | 3.54e-07 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 349      |
# |    iterations         | 1500     |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 7500     |
# | train/                |          |
# |    entropy_loss       | -0.684   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | 0.000651 |
# |    value_loss         | 1.31e-06 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 347       |
# |    iterations         | 1600      |
# |    time_elapsed       | 23        |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -0.693    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1599      |
# |    policy_loss        | -0.000231 |
# |    value_loss         | 1.31e-07  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 349      |
# |    iterations         | 1700     |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -0.693   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | 0.00145  |
# |    value_loss         | 6.21e-06 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 352      |
# |    iterations         | 1800     |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 9000     |
# | train/                |          |
# |    entropy_loss       | -0.674   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | 5.06e-05 |
# |    value_loss         | 1.21e-07 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 353      |
# |    iterations         | 1900     |
# |    time_elapsed       | 26       |
# |    total_timesteps    | 9500     |
# | train/                |          |
# |    entropy_loss       | -0.655   |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | 0.000706 |
# |    value_loss         | 1.12e-06 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 354      |
# |    iterations         | 2000     |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.479   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1999     |
# |    policy_loss        | 0.000551 |
# |    value_loss         | 7.47e-06 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 356      |
# |    iterations         | 2100     |
# |    time_elapsed       | 29       |
# |    total_timesteps    | 10500    |
# | train/                |          |
# |    entropy_loss       | -0.498   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2099     |
# |    policy_loss        | 0.000249 |
# |    value_loss         | 1.28e-06 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 354       |
# |    iterations         | 2200      |
# |    time_elapsed       | 30        |
# |    total_timesteps    | 11000     |
# | train/                |           |
# |    entropy_loss       | -0.554    |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2199      |
# |    policy_loss        | 0.000451  |
# |    value_loss         | 5.27e-06  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 354      |
# |    iterations         | 2300     |
# |    time_elapsed       | 32       |
# |    total_timesteps    | 11500    |
# | train/                |          |
# |    entropy_loss       | -0.504   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2299     |
# |    policy_loss        | 0.00133  |
# |    value_loss         | 5.73e-06 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 353      |
# |    iterations         | 2400     |
# |    time_elapsed       | 33       |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -0.455   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2399     |
# |    policy_loss        | 0.00103  |
# |    value_loss         | 4.26e-06 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 354      |
# |    iterations         | 2500     |
# |    time_elapsed       | 35       |
# |    total_timesteps    | 12500    |
# | train/                |          |
# |    entropy_loss       | -0.399   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2499     |
# |    policy_loss        | 0.0012   |
# |    value_loss         | 8.67e-06 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 356      |
# |    iterations         | 2600     |
# |    time_elapsed       | 36       |
# |    total_timesteps    | 13000    |
# | train/                |          |
# |    entropy_loss       | -0.446   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2599     |
# |    policy_loss        | 0.000695 |
# |    value_loss         | 1.85e-06 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 354      |
# |    iterations         | 2700     |
# |    time_elapsed       | 38       |
# |    total_timesteps    | 13500    |
# | train/                |          |
# |    entropy_loss       | -0.577   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2699     |
# |    policy_loss        | 0.000599 |
# |    value_loss         | 8.79e-07 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 355       |
# |    iterations         | 2800      |
# |    time_elapsed       | 39        |
# |    total_timesteps    | 14000     |
# | train/                |           |
# |    entropy_loss       | -0.528    |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2799      |
# |    policy_loss        | 8.95e-05  |
# |    value_loss         | 8.36e-08  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 357       |
# |    iterations         | 2900      |
# |    time_elapsed       | 40        |
# |    total_timesteps    | 14500     |
# | train/                |           |
# |    entropy_loss       | -0.589    |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2899      |
# |    policy_loss        | -0.000192 |
# |    value_loss         | 2.01e-07  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 358      |
# |    iterations         | 3000     |
# |    time_elapsed       | 41       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.573   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2999     |
# |    policy_loss        | 9.01e-05 |
# |    value_loss         | 3.44e-07 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 357      |
# |    iterations         | 3100     |
# |    time_elapsed       | 43       |
# |    total_timesteps    | 15500    |
# | train/                |          |
# |    entropy_loss       | -0.619   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3099     |
# |    policy_loss        | 0.00135  |
# |    value_loss         | 7.03e-06 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 357       |
# |    iterations         | 3200      |
# |    time_elapsed       | 44        |
# |    total_timesteps    | 16000     |
# | train/                |           |
# |    entropy_loss       | -0.607    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3199      |
# |    policy_loss        | -0.000133 |
# |    value_loss         | 1.02e-07  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 357      |
# |    iterations         | 3300     |
# |    time_elapsed       | 46       |
# |    total_timesteps    | 16500    |
# | train/                |          |
# |    entropy_loss       | -0.594   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3299     |
# |    policy_loss        | 5.31e-05 |
# |    value_loss         | 9.57e-08 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 358       |
# |    iterations         | 3400      |
# |    time_elapsed       | 47        |
# |    total_timesteps    | 17000     |
# | train/                |           |
# |    entropy_loss       | -0.642    |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3399      |
# |    policy_loss        | 0.000564  |
# |    value_loss         | 1.17e-06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 360       |
# |    iterations         | 3500      |
# |    time_elapsed       | 48        |
# |    total_timesteps    | 17500     |
# | train/                |           |
# |    entropy_loss       | -0.677    |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3499      |
# |    policy_loss        | -0.000189 |
# |    value_loss         | 9.42e-07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 359       |
# |    iterations         | 3600      |
# |    time_elapsed       | 50        |
# |    total_timesteps    | 18000     |
# | train/                |           |
# |    entropy_loss       | -0.692    |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3599      |
# |    policy_loss        | -0.00174  |
# |    value_loss         | 7.46e-06  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 360      |
# |    iterations         | 3700     |
# |    time_elapsed       | 51       |
# |    total_timesteps    | 18500    |
# | train/                |          |
# |    entropy_loss       | -0.693   |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3699     |
# |    policy_loss        | 0.000835 |
# |    value_loss         | 1.7e-06  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 360      |
# |    iterations         | 3800     |
# |    time_elapsed       | 52       |
# |    total_timesteps    | 19000    |
# | train/                |          |
# |    entropy_loss       | -0.693   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3799     |
# |    policy_loss        | 0.00109  |
# |    value_loss         | 3.14e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.93e+04 |
# |    ep_rew_mean        | 0.415    |
# | time/                 |          |
# |    fps                | 360      |
# |    iterations         | 3900     |
# |    time_elapsed       | 54       |
# |    total_timesteps    | 19500    |
# | train/                |          |
# |    entropy_loss       | -0.692   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3899     |
# |    policy_loss        | -0.00365 |
# |    value_loss         | 3.09e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 1.93e+04  |
# |    ep_rew_mean        | 0.415     |
# | time/                 |           |
# |    fps                | 361       |
# |    iterations         | 4000      |
# |    time_elapsed       | 55        |
# |    total_timesteps    | 20000     |
# | train/                |           |
# |    entropy_loss       | -0.689    |
# |    explained_variance | 3.5e-05   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3999      |
# |    policy_loss        | -0.000183 |
# |    value_loss         | 7.94e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.93e+04 |
# |    ep_rew_mean        | 0.415    |
# | time/                 |          |
# |    fps                | 362      |
# |    iterations         | 4100     |
# |    time_elapsed       | 56       |
# |    total_timesteps    | 20500    |
# | train/                |          |
# |    entropy_loss       | -0.683   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4099     |
# |    policy_loss        | 0.00248  |
# |    value_loss         | 1.79e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 1.93e+04  |
# |    ep_rew_mean        | 0.415     |
# | time/                 |           |
# |    fps                | 361       |
# |    iterations         | 4200      |
# |    time_elapsed       | 58        |
# |    total_timesteps    | 21000     |
# | train/                |           |
# |    entropy_loss       | -0.684    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4199      |
# |    policy_loss        | -0.000179 |
# |    value_loss         | 5.96e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.93e+04 |
# |    ep_rew_mean        | 0.415    |
# | time/                 |          |
# |    fps                | 361      |
# |    iterations         | 4300     |
# |    time_elapsed       | 59       |
# |    total_timesteps    | 21500    |
# | train/                |          |
# |    entropy_loss       | -0.688   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4299     |
# |    policy_loss        | -0.00165 |
# |    value_loss         | 5.32e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.93e+04 |
# |    ep_rew_mean        | 0.415    |
# | time/                 |          |
# |    fps                | 363      |
# |    iterations         | 4400     |
# |    time_elapsed       | 60       |
# |    total_timesteps    | 22000    |
# | train/                |          |
# |    entropy_loss       | -0.685   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4399     |
# |    policy_loss        | -0.0011  |
# |    value_loss         | 3.89e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.93e+04 |
# |    ep_rew_mean        | 0.415    |
# | time/                 |          |
# |    fps                | 364      |
# |    iterations         | 4500     |
# |    time_elapsed       | 61       |
# |    total_timesteps    | 22500    |
# | train/                |          |
# |    entropy_loss       | -0.69    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4499     |
# |    policy_loss        | 9.85e-05 |
# |    value_loss         | 4.62e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.93e+04 |
# |    ep_rew_mean        | 0.415    |
# | time/                 |          |
# |    fps                | 365      |
# |    iterations         | 4600     |
# |    time_elapsed       | 62       |
# |    total_timesteps    | 23000    |
# | train/                |          |
# |    entropy_loss       | -0.685   |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4599     |
# |    policy_loss        | 6.23e-05 |
# |    value_loss         | 2.47e-07 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 1.93e+04  |
# |    ep_rew_mean        | 0.415     |
# | time/                 |           |
# |    fps                | 365       |
# |    iterations         | 4700      |
# |    time_elapsed       | 64        |
# |    total_timesteps    | 23500     |
# | train/                |           |
# |    entropy_loss       | -0.67     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4699      |
# |    policy_loss        | 0.000551  |
# |    value_loss         | 1.12e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 1.93e+04  |
# |    ep_rew_mean        | 0.415     |
# | time/                 |           |
# |    fps                | 366       |
# |    iterations         | 4800      |
# |    time_elapsed       | 65        |
# |    total_timesteps    | 24000     |
# | train/                |           |
# |    entropy_loss       | -0.668    |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4799      |
# |    policy_loss        | -0.000378 |
# |    value_loss         | 8.84e-07  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 1.93e+04  |
# |    ep_rew_mean        | 0.415     |
# | time/                 |           |
# |    fps                | 365       |
# |    iterations         | 4900      |
# |    time_elapsed       | 66        |
# |    total_timesteps    | 24500     |
# | train/                |           |
# |    entropy_loss       | -0.639    |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4899      |
# |    policy_loss        | -0.000476 |
# |    value_loss         | 2.4e-06   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.93e+04 |
# |    ep_rew_mean        | 0.415    |
# | time/                 |          |
# |    fps                | 365      |
# |    iterations         | 5000     |
# |    time_elapsed       | 68       |
# |    total_timesteps    | 25000    |
# | train/                |          |
# |    entropy_loss       | -0.443   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4999     |
# |    policy_loss        | 0.000417 |
# |    value_loss         | 8.99e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.93e+04 |
# |    ep_rew_mean        | 0.415    |
# | time/                 |          |
# |    fps                | 364      |
# |    iterations         | 5100     |
# |    time_elapsed       | 69       |
# |    total_timesteps    | 25500    |
# | train/                |          |
# |    entropy_loss       | -0.537   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5099     |
# |    policy_loss        | 0.00033  |
# |    value_loss         | 2.44e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 1.93e+04  |
# |    ep_rew_mean        | 0.415     |
# | time/                 |           |
# |    fps                | 364       |
# |    iterations         | 5200      |
# |    time_elapsed       | 71        |
# |    total_timesteps    | 26000     |
# | train/                |           |
# |    entropy_loss       | -0.53     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5199      |
# |    policy_loss        | 0.000784  |
# |    value_loss         | 2.12e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 1.93e+04  |
# |    ep_rew_mean        | 0.415     |
# | time/                 |           |
# |    fps                | 364       |
# |    iterations         | 5300      |
# |    time_elapsed       | 72        |
# |    total_timesteps    | 26500     |
# | train/                |           |
# |    entropy_loss       | -0.531    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5299      |
# |    policy_loss        | -0.000201 |
# |    value_loss         | 2.28e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 1.93e+04  |
# |    ep_rew_mean        | 0.415     |
# | time/                 |           |
# |    fps                | 365       |
# |    iterations         | 5400      |
# |    time_elapsed       | 73        |
# |    total_timesteps    | 27000     |
# | train/                |           |
# |    entropy_loss       | -0.572    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5399      |
# |    policy_loss        | -0.000562 |
# |    value_loss         | 1.08e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 1.93e+04  |
# |    ep_rew_mean        | 0.415     |
# | time/                 |           |
# |    fps                | 366       |
# |    iterations         | 5500      |
# |    time_elapsed       | 75        |
# |    total_timesteps    | 27500     |
# | train/                |           |
# |    entropy_loss       | -0.612    |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5499      |
# |    policy_loss        | 0.00147   |
# |    value_loss         | 1.11e-05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.93e+04 |
# |    ep_rew_mean        | 0.415    |
# | time/                 |          |
# |    fps                | 366      |
# |    iterations         | 5600     |
# |    time_elapsed       | 76       |
# |    total_timesteps    | 28000    |
# | train/                |          |
# |    entropy_loss       | -0.554   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5599     |
# |    policy_loss        | -0.00177 |
# |    value_loss         | 1.42e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 1.93e+04  |
# |    ep_rew_mean        | 0.415     |
# | time/                 |           |
# |    fps                | 366       |
# |    iterations         | 5700      |
# |    time_elapsed       | 77        |
# |    total_timesteps    | 28500     |
# | train/                |           |
# |    entropy_loss       | -0.678    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5699      |
# |    policy_loss        | -0.000895 |
# |    value_loss         | 2.96e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.93e+04 |
# |    ep_rew_mean        | 0.415    |
# | time/                 |          |
# |    fps                | 367      |
# |    iterations         | 5800     |
# |    time_elapsed       | 78       |
# |    total_timesteps    | 29000    |
# | train/                |          |
# |    entropy_loss       | -0.662   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5799     |
# |    policy_loss        | -0.00147 |
# |    value_loss         | 3.58e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 1.93e+04  |
# |    ep_rew_mean        | 0.415     |
# | time/                 |           |
# |    fps                | 369       |
# |    iterations         | 5900      |
# |    time_elapsed       | 79        |
# |    total_timesteps    | 29500     |
# | train/                |           |
# |    entropy_loss       | -0.658    |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5899      |
# |    policy_loss        | -0.00091  |
# |    value_loss         | 6.71e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.93e+04 |
# |    ep_rew_mean        | 0.415    |
# | time/                 |          |
# |    fps                | 370      |
# |    iterations         | 6000     |
# |    time_elapsed       | 81       |
# |    total_timesteps    | 30000    |
# | train/                |          |
# |    entropy_loss       | -0.654   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5999     |
# |    policy_loss        | 0.000601 |
# |    value_loss         | 9.15e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.93e+04 |
# |    ep_rew_mean        | 0.415    |
# | time/                 |          |
# |    fps                | 371      |
# |    iterations         | 6100     |
# |    time_elapsed       | 82       |
# |    total_timesteps    | 30500    |
# | train/                |          |
# |    entropy_loss       | -0.676   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6099     |
# |    policy_loss        | 0.00128  |
# |    value_loss         | 4.34e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 1.93e+04  |
# |    ep_rew_mean        | 0.415     |
# | time/                 |           |
# |    fps                | 371       |
# |    iterations         | 6200      |
# |    time_elapsed       | 83        |
# |    total_timesteps    | 31000     |
# | train/                |           |
# |    entropy_loss       | -0.691    |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6199      |
# |    policy_loss        | -0.000583 |
# |    value_loss         | 7.88e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.93e+04 |
# |    ep_rew_mean        | 0.415    |
# | time/                 |          |
# |    fps                | 368      |
# |    iterations         | 6300     |
# |    time_elapsed       | 85       |
# |    total_timesteps    | 31500    |
# | train/                |          |
# |    entropy_loss       | -0.689   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6299     |
# |    policy_loss        | 0.000739 |
# |    value_loss         | 1.12e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 1.93e+04  |
# |    ep_rew_mean        | 0.415     |
# | time/                 |           |
# |    fps                | 364       |
# |    iterations         | 6400      |
# |    time_elapsed       | 87        |
# |    total_timesteps    | 32000     |
# | train/                |           |
# |    entropy_loss       | -0.679    |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6399      |
# |    policy_loss        | 0.000121  |
# |    value_loss         | 3.03e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.93e+04 |
# |    ep_rew_mean        | 0.415    |
# | time/                 |          |
# |    fps                | 363      |
# |    iterations         | 6500     |
# |    time_elapsed       | 89       |
# |    total_timesteps    | 32500    |
# | train/                |          |
# |    entropy_loss       | -0.687   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6499     |
# |    policy_loss        | 0.00133  |
# |    value_loss         | 3.68e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.93e+04 |
# |    ep_rew_mean        | 0.415    |
# | time/                 |          |
# |    fps                | 363      |
# |    iterations         | 6600     |
# |    time_elapsed       | 90       |
# |    total_timesteps    | 33000    |
# | train/                |          |
# |    entropy_loss       | -0.693   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6599     |
# |    policy_loss        | 9.73e-06 |
# |    value_loss         | 4.28e-08 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.93e+04 |
# |    ep_rew_mean        | 0.415    |
# | time/                 |          |
# |    fps                | 362      |
# |    iterations         | 6700     |
# |    time_elapsed       | 92       |
# |    total_timesteps    | 33500    |
# | train/                |          |
# |    entropy_loss       | -0.69    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6699     |
# |    policy_loss        | 0.000122 |
# |    value_loss         | 1.72e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.93e+04 |
# |    ep_rew_mean        | 0.415    |
# | time/                 |          |
# |    fps                | 360      |
# |    iterations         | 6800     |
# |    time_elapsed       | 94       |
# |    total_timesteps    | 34000    |
# | train/                |          |
# |    entropy_loss       | -0.687   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6799     |
# |    policy_loss        | -0.00129 |
# |    value_loss         | 5.08e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.93e+04 |
# |    ep_rew_mean        | 0.415    |
# | time/                 |          |
# |    fps                | 360      |
# |    iterations         | 6900     |
# |    time_elapsed       | 95       |
# |    total_timesteps    | 34500    |
# | train/                |          |
# |    entropy_loss       | -0.685   |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6899     |
# |    policy_loss        | 0.000802 |
# |    value_loss         | 1.5e-06  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 1.93e+04  |
# |    ep_rew_mean        | 0.415     |
# | time/                 |           |
# |    fps                | 359       |
# |    iterations         | 7000      |
# |    time_elapsed       | 97        |
# |    total_timesteps    | 35000     |
# | train/                |           |
# |    entropy_loss       | -0.658    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6999      |
# |    policy_loss        | -0.000721 |
# |    value_loss         | 2.03e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 1.93e+04  |
# |    ep_rew_mean        | 0.415     |
# | time/                 |           |
# |    fps                | 359       |
# |    iterations         | 7100      |
# |    time_elapsed       | 98        |
# |    total_timesteps    | 35500     |
# | train/                |           |
# |    entropy_loss       | -0.684    |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7099      |
# |    policy_loss        | -0.000223 |
# |    value_loss         | 2.44e-07  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 1.93e+04  |
# |    ep_rew_mean        | 0.415     |
# | time/                 |           |
# |    fps                | 359       |
# |    iterations         | 7200      |
# |    time_elapsed       | 100       |
# |    total_timesteps    | 36000     |
# | train/                |           |
# |    entropy_loss       | -0.65     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7199      |
# |    policy_loss        | -0.000443 |
# |    value_loss         | 2.66e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.93e+04 |
# |    ep_rew_mean        | 0.415    |
# | time/                 |          |
# |    fps                | 360      |
# |    iterations         | 7300     |
# |    time_elapsed       | 101      |
# |    total_timesteps    | 36500    |
# | train/                |          |
# |    entropy_loss       | -0.693   |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7299     |
# |    policy_loss        | 1.46e-05 |
# |    value_loss         | 1.86e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.93e+04 |
# |    ep_rew_mean        | 0.415    |
# | time/                 |          |
# |    fps                | 361      |
# |    iterations         | 7400     |
# |    time_elapsed       | 102      |
# |    total_timesteps    | 37000    |
# | train/                |          |
# |    entropy_loss       | -0.682   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7399     |
# |    policy_loss        | -0.00236 |
# |    value_loss         | 1.05e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 1.93e+04  |
# |    ep_rew_mean        | 0.415     |
# | time/                 |           |
# |    fps                | 361       |
# |    iterations         | 7500      |
# |    time_elapsed       | 103       |
# |    total_timesteps    | 37500     |
# | train/                |           |
# |    entropy_loss       | -0.679    |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7499      |
# |    policy_loss        | -0.000557 |
# |    value_loss         | 2.69e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.93e+04 |
# |    ep_rew_mean        | 0.415    |
# | time/                 |          |
# |    fps                | 362      |
# |    iterations         | 7600     |
# |    time_elapsed       | 104      |
# |    total_timesteps    | 38000    |
# | train/                |          |
# |    entropy_loss       | -0.667   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7599     |
# |    policy_loss        | -0.00143 |
# |    value_loss         | 6.61e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.93e+04 |
# |    ep_rew_mean        | 0.415    |
# | time/                 |          |
# |    fps                | 363      |
# |    iterations         | 7700     |
# |    time_elapsed       | 105      |
# |    total_timesteps    | 38500    |
# | train/                |          |
# |    entropy_loss       | -0.678   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7699     |
# |    policy_loss        | 0.000945 |
# |    value_loss         | 2.47e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 1.93e+04  |
# |    ep_rew_mean        | 0.305     |
# | time/                 |           |
# |    fps                | 364       |
# |    iterations         | 7800      |
# |    time_elapsed       | 106       |
# |    total_timesteps    | 39000     |
# | train/                |           |
# |    entropy_loss       | -0.693    |
# |    explained_variance | -2.63e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7799      |
# |    policy_loss        | 0.00283   |
# |    value_loss         | 1.83e-05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 1.93e+04  |
# |    ep_rew_mean        | 0.305     |
# | time/                 |           |
# |    fps                | 365       |
# |    iterations         | 7900      |
# |    time_elapsed       | 108       |
# |    total_timesteps    | 39500     |
# | train/                |           |
# |    entropy_loss       | -0.693    |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7899      |
# |    policy_loss        | -4.96e-05 |
# |    value_loss         | 1.48e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 1.93e+04  |
# |    ep_rew_mean        | 0.305     |
# | time/                 |           |
# |    fps                | 365       |
# |    iterations         | 8000      |
# |    time_elapsed       | 109       |
# |    total_timesteps    | 40000     |
# | train/                |           |
# |    entropy_loss       | -0.69     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7999      |
# |    policy_loss        | 0.000302  |
# |    value_loss         | 1.6e-06   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.93e+04 |
# |    ep_rew_mean        | 0.305    |
# | time/                 |          |
# |    fps                | 364      |
# |    iterations         | 8100     |
# |    time_elapsed       | 111      |
# |    total_timesteps    | 40500    |
# | train/                |          |
# |    entropy_loss       | -0.692   |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8099     |
# |    policy_loss        | -0.00196 |
# |    value_loss         | 9.7e-06  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.93e+04 |
# |    ep_rew_mean        | 0.305    |
# | time/                 |          |
# |    fps                | 364      |
# |    iterations         | 8200     |
# |    time_elapsed       | 112      |
# |    total_timesteps    | 41000    |
# | train/                |          |
# |    entropy_loss       | -0.689   |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8199     |
# |    policy_loss        | 0.00339  |
# |    value_loss         | 4.68e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.93e+04 |
# |    ep_rew_mean        | 0.305    |
# | time/                 |          |
# |    fps                | 363      |
# |    iterations         | 8300     |
# |    time_elapsed       | 114      |
# |    total_timesteps    | 41500    |
# | train/                |          |
# |    entropy_loss       | -0.691   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8299     |
# |    policy_loss        | 0.000666 |
# |    value_loss         | 1.58e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 1.93e+04  |
# |    ep_rew_mean        | 0.305     |
# | time/                 |           |
# |    fps                | 364       |
# |    iterations         | 8400      |
# |    time_elapsed       | 115       |
# |    total_timesteps    | 42000     |
# | train/                |           |
# |    entropy_loss       | -0.689    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8399      |
# |    policy_loss        | -0.000851 |
# |    value_loss         | 2.62e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 1.93e+04  |
# |    ep_rew_mean        | 0.305     |
# | time/                 |           |
# |    fps                | 365       |
# |    iterations         | 8500      |
# |    time_elapsed       | 116       |
# |    total_timesteps    | 42500     |
# | train/                |           |
# |    entropy_loss       | -0.688    |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8499      |
# |    policy_loss        | 0.000398  |
# |    value_loss         | 8.19e-07  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 1.93e+04  |
# |    ep_rew_mean        | 0.305     |
# | time/                 |           |
# |    fps                | 365       |
# |    iterations         | 8600      |
# |    time_elapsed       | 117       |
# |    total_timesteps    | 43000     |
# | train/                |           |
# |    entropy_loss       | -0.669    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8599      |
# |    policy_loss        | -0.000511 |
# |    value_loss         | 1.22e-05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 1.93e+04  |
# |    ep_rew_mean        | 0.305     |
# | time/                 |           |
# |    fps                | 366       |
# |    iterations         | 8700      |
# |    time_elapsed       | 118       |
# |    total_timesteps    | 43500     |
# | train/                |           |
# |    entropy_loss       | -0.688    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8699      |
# |    policy_loss        | -0.000916 |
# |    value_loss         | 1.77e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 1.93e+04  |
# |    ep_rew_mean        | 0.305     |
# | time/                 |           |
# |    fps                | 366       |
# |    iterations         | 8800      |
# |    time_elapsed       | 120       |
# |    total_timesteps    | 44000     |
# | train/                |           |
# |    entropy_loss       | -0.692    |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8799      |
# |    policy_loss        | 0.00442   |
# |    value_loss         | 4.43e-05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 1.93e+04  |
# |    ep_rew_mean        | 0.305     |
# | time/                 |           |
# |    fps                | 366       |
# |    iterations         | 8900      |
# |    time_elapsed       | 121       |
# |    total_timesteps    | 44500     |
# | train/                |           |
# |    entropy_loss       | -0.692    |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8899      |
# |    policy_loss        | -0.000254 |
# |    value_loss         | 8.44e-07  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 1.93e+04  |
# |    ep_rew_mean        | 0.305     |
# | time/                 |           |
# |    fps                | 366       |
# |    iterations         | 9000      |
# |    time_elapsed       | 122       |
# |    total_timesteps    | 45000     |
# | train/                |           |
# |    entropy_loss       | -0.688    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8999      |
# |    policy_loss        | -0.000276 |
# |    value_loss         | 2.68e-07  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 1.93e+04  |
# |    ep_rew_mean        | 0.305     |
# | time/                 |           |
# |    fps                | 367       |
# |    iterations         | 9100      |
# |    time_elapsed       | 123       |
# |    total_timesteps    | 45500     |
# | train/                |           |
# |    entropy_loss       | -0.693    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9099      |
# |    policy_loss        | -0.000562 |
# |    value_loss         | 8.88e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.93e+04 |
# |    ep_rew_mean        | 0.305    |
# | time/                 |          |
# |    fps                | 367      |
# |    iterations         | 9200     |
# |    time_elapsed       | 125      |
# |    total_timesteps    | 46000    |
# | train/                |          |
# |    entropy_loss       | -0.693   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9199     |
# |    policy_loss        | 0.000476 |
# |    value_loss         | 5.28e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.93e+04 |
# |    ep_rew_mean        | 0.305    |
# | time/                 |          |
# |    fps                | 367      |
# |    iterations         | 9300     |
# |    time_elapsed       | 126      |
# |    total_timesteps    | 46500    |
# | train/                |          |
# |    entropy_loss       | -0.693   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9299     |
# |    policy_loss        | -0.0017  |
# |    value_loss         | 9.68e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.93e+04 |
# |    ep_rew_mean        | 0.305    |
# | time/                 |          |
# |    fps                | 367      |
# |    iterations         | 9400     |
# |    time_elapsed       | 127      |
# |    total_timesteps    | 47000    |
# | train/                |          |
# |    entropy_loss       | -0.689   |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9399     |
# |    policy_loss        | 0.000121 |
# |    value_loss         | 1.15e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 1.93e+04  |
# |    ep_rew_mean        | 0.305     |
# | time/                 |           |
# |    fps                | 368       |
# |    iterations         | 9500      |
# |    time_elapsed       | 129       |
# |    total_timesteps    | 47500     |
# | train/                |           |
# |    entropy_loss       | -0.686    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9499      |
# |    policy_loss        | -0.000353 |
# |    value_loss         | 4.77e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.93e+04 |
# |    ep_rew_mean        | 0.305    |
# | time/                 |          |
# |    fps                | 368      |
# |    iterations         | 9600     |
# |    time_elapsed       | 130      |
# |    total_timesteps    | 48000    |
# | train/                |          |
# |    entropy_loss       | -0.683   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9599     |
# |    policy_loss        | -0.00081 |
# |    value_loss         | 2.21e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 1.93e+04  |
# |    ep_rew_mean        | 0.305     |
# | time/                 |           |
# |    fps                | 369       |
# |    iterations         | 9700      |
# |    time_elapsed       | 131       |
# |    total_timesteps    | 48500     |
# | train/                |           |
# |    entropy_loss       | -0.688    |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9699      |
# |    policy_loss        | -0.000163 |
# |    value_loss         | 9.53e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.93e+04 |
# |    ep_rew_mean        | 0.305    |
# | time/                 |          |
# |    fps                | 369      |
# |    iterations         | 9800     |
# |    time_elapsed       | 132      |
# |    total_timesteps    | 49000    |
# | train/                |          |
# |    entropy_loss       | -0.682   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9799     |
# |    policy_loss        | 0.000624 |
# |    value_loss         | 7.4e-07  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.93e+04 |
# |    ep_rew_mean        | 0.305    |
# | time/                 |          |
# |    fps                | 369      |
# |    iterations         | 9900     |
# |    time_elapsed       | 133      |
# |    total_timesteps    | 49500    |
# | train/                |          |
# |    entropy_loss       | -0.686   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9899     |
# |    policy_loss        | 0.000156 |
# |    value_loss         | 4.21e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.93e+04 |
# |    ep_rew_mean        | 0.305    |
# | time/                 |          |
# |    fps                | 370      |
# |    iterations         | 10000    |
# |    time_elapsed       | 135      |
# |    total_timesteps    | 50000    |
# | train/                |          |
# |    entropy_loss       | -0.679   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9999     |
# |    policy_loss        | -0.0013  |
# |    value_loss         | 7.1e-06  |
# ------------------------------------
# 0.0007417285055248968 243.4772847104428
# 5746 5750 0

# %%
test_env=train_env(all_test,price_test,vol_test,sharpe_test,maxDiv_test)
episodes = 1
A2CrewardList=[]
A2CunweightedRewardList=[]
A2CsharpeRewardList=[]
A2CmarkRewardList=[]
test_env.reset()
obvs=test_env.reset()
done=False
while done == False:
  action,_states=A2Cmodel.predict(obvs)
  obvs,rewards,done,info=test_env.step(action)
  #print('NW',test_env.net_worth)
  A2CrewardList.append(test_env.net_worth)
  A2CunweightedRewardList.append(test_env.even_net_worth)
  A2CsharpeRewardList.append(test_env.sharpe_net_worth)
  A2CmarkRewardList.append(test_env.mark_net_worth)

# %%
plt.figure(figsize=(10,10))
plt.plot(A2CrewardList,linewidth=3, color='black', label='Robot Return')
plt.plot(A2CunweightedRewardList,linewidth=3,color='orange',label='Baseline Portfolio')
plt.plot(A2CsharpeRewardList,linewidth=1,color='blue',label='Sharpe',linestyle='dashed')
plt.plot(A2CmarkRewardList,linewidth=1,color='purple',label='Max Diverse',linestyle='dashed')
plt.title('A2C')
plt.legend()
print(A2CrewardList[-1]/A2CunweightedRewardList[-1])
print(A2CrewardList[-1])
# Out:
# 1.1816260608100346
# 169.95603471336122

# %%
test_env=train_env(all_test,price_test,vol_test,sharpe_test,maxDiv_test)
episodes = 1
A2CrewardList2=[]
A2CunweightedRewardList2=[]
A2CsharpeRewardList2=[]
A2CmarkRewardList2=[]
test_env.reset()
obvs=test_env.reset()
done=False
while done == False:
  action,_states=A2Cmodel.predict(obvs)
  obvs,rewards,done,info=test_env.step(action)
  #print('NW',test_env.net_worth)
  A2CrewardList2.append(test_env.net_worth)
  A2CunweightedRewardList2.append(test_env.even_net_worth)
  A2CsharpeRewardList2.append(test_env.sharpe_net_worth)
  A2CmarkRewardList2.append(test_env.mark_net_worth)

# %%
plt.figure(figsize=(10,10))
plt.plot(A2CrewardList2,linewidth=3, color='black', label='Robot Return')
plt.plot(A2CunweightedRewardList2,linewidth=3,color='orange',label='Baseline Portfolio')
plt.plot(A2CsharpeRewardList2,linewidth=1,color='blue',label='Sharpe',linestyle='dashed')
plt.plot(A2CmarkRewardList2,linewidth=1,color='purple',label='Max Diverse',linestyle='dashed')
plt.title('A2C')
plt.legend()
print(A2CrewardList2[-1]/A2CunweightedRewardList2[-1])
print(A2CrewardList2[-1])
# Out:
# 1.182420563564403
# 170.07030989920867

# %%
test_env=train_env(all_test,price_test,vol_test,sharpe_test,maxDiv_test)
episodes = 1
A2CrewardList3=[]
A2CunweightedRewardList3=[]
A2CsharpeRewardList3=[]
A2CmarkRewardList3=[]
test_env.reset()
obvs=test_env.reset()
done=False
while done == False:
  action,_states=A2Cmodel.predict(obvs)
  obvs,rewards,done,info=test_env.step(action)
  #print('NW',test_env.net_worth)
  A2CrewardList3.append(test_env.net_worth)
  A2CunweightedRewardList3.append(test_env.even_net_worth)
  A2CsharpeRewardList3.append(test_env.sharpe_net_worth)
  A2CmarkRewardList3.append(test_env.mark_net_worth)

# %%
plt.figure(figsize=(10,10))
plt.plot(A2CrewardList3,linewidth=3, color='black', label='Robot Return')
plt.plot(A2CunweightedRewardList3,linewidth=3,color='orange',label='Baseline Portfolio')
plt.plot(A2CsharpeRewardList3,linewidth=1,color='blue',label='Sharpe',linestyle='dashed')
plt.plot(A2CmarkRewardList3,linewidth=1,color='purple',label='Max Diverse',linestyle='dashed')
plt.title('A2C')
plt.legend()
print(A2CrewardList3[-1]/A2CunweightedRewardList3[-1])
print(A2CrewardList3[-1])
# Out:
# 1.1000533835050559
# 158.223246113385

# %%
test_env=train_env(all_test,price_test,vol_test,sharpe_test,maxDiv_test)
episodes = 1
A2CrewardList4=[]
A2CunweightedRewardList4=[]
A2CsharpeRewardList4=[]
A2CmarkRewardList4=[]
test_env.reset()
obvs=test_env.reset()
done=False
while done == False:
  action,_states=A2Cmodel.predict(obvs)
  obvs,rewards,done,info=test_env.step(action)
  #print('NW',test_env.net_worth)
  A2CrewardList4.append(test_env.net_worth)
  A2CunweightedRewardList4.append(test_env.even_net_worth)
  A2CsharpeRewardList4.append(test_env.sharpe_net_worth)
  A2CmarkRewardList4.append(test_env.mark_net_worth)

# %%
plt.figure(figsize=(10,10))
plt.plot(A2CrewardList4,linewidth=3, color='black', label='Robot Return')
plt.plot(A2CunweightedRewardList4,linewidth=3,color='orange',label='Baseline Portfolio')
plt.plot(A2CsharpeRewardList4,linewidth=1,color='blue',label='Sharpe',linestyle='dashed')
plt.plot(A2CmarkRewardList4,linewidth=1,color='purple',label='Max Diverse',linestyle='dashed')
plt.title('A2C')
plt.legend()
print(A2CrewardList4[-1]/A2CunweightedRewardList4[-1])
print(A2CrewardList4[-1])
# Out:
# 1.0239189308282888
# 147.27265005667223

# %%
test_env=train_env(all_test,price_test,vol_test,sharpe_test,maxDiv_test)
episodes = 1
A2CrewardList5=[]
A2CunweightedRewardList5=[]
A2CsharpeRewardList5=[]
A2CmarkRewardList5=[]
test_env.reset()
obvs=test_env.reset()
done=False
while done == False:
  action,_states=A2Cmodel.predict(obvs)
  obvs,rewards,done,info=test_env.step(action)
  #print('NW',test_env.net_worth)
  A2CrewardList5.append(test_env.net_worth)
  A2CunweightedRewardList5.append(test_env.even_net_worth)
  A2CsharpeRewardList5.append(test_env.sharpe_net_worth)
  A2CmarkRewardList5.append(test_env.mark_net_worth)

# %%
plt.figure(figsize=(10,10))
plt.plot(A2CrewardList5,linewidth=3, color='black', label='Robot Return')
plt.plot(A2CunweightedRewardList5,linewidth=3,color='orange',label='Baseline Portfolio')
plt.plot(A2CsharpeRewardList5,linewidth=1,color='blue',label='Sharpe',linestyle='dashed')
plt.plot(A2CmarkRewardList5,linewidth=1,color='purple',label='Max Diverse',linestyle='dashed')
plt.title('A2C')
plt.legend()
print(A2CrewardList5[-1]/A2CunweightedRewardList5[-1])
print(A2CrewardList5[-1])
# Out:
# 1.0362393833519734
# 149.0447295040096

# %% [markdown]
# # TRPO Model 50,000 timesteps
# I expect that the TRPO model will converge on a viable strategy more easily than PPO.

# %%
env=train_env(all_train,price_train,vol_train,sharpe_train,maxDiv_train)
env.reset()
#env.step(env.action_space.sample())
TRPOmodel = TRPO('MlpPolicy', env, verbose=1)
TRPOmodel.learn(total_timesteps=50000)
print(env.reward,env.net_worth)
print(env.action1ct,env.action2ct,env.action3ct)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# -----------------------------
# | time/              |      |
# |    fps             | 502  |
# |    iterations      | 1    |
# |    time_elapsed    | 4    |
# |    total_timesteps | 2048 |
# -----------------------------
# ----------------------------------------
# | time/                     |          |
# |    fps                    | 545      |
# |    iterations             | 2        |
# |    time_elapsed           | 7        |
# |    total_timesteps        | 4096     |
# | train/                    |          |
# |    explained_variance     | 0.00836  |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00384  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 1        |
# |    policy_objective       | 0.000251 |
# |    value_loss             | 0.000796 |
# ----------------------------------------
# -----------------------------------------
# | time/                     |           |
# |    fps                    | 575       |
# |    iterations             | 3         |
# |    time_elapsed           | 10        |
# |    total_timesteps        | 6144      |
# | train/                    |           |
# |    explained_variance     | -8.11e-06 |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00967   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 2         |
# |    policy_objective       | 0.00339   |
# |    value_loss             | 0.000576  |
# -----------------------------------------
# ----------------------------------------
# | time/                     |          |
# |    fps                    | 592      |
# |    iterations             | 4        |
# |    time_elapsed           | 13       |
# |    total_timesteps        | 8192     |
# | train/                    |          |
# |    explained_variance     | 0.000805 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00656  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 3        |
# |    policy_objective       | 0.00267  |
# |    value_loss             | 0.00043  |
# ----------------------------------------
# ----------------------------------------
# | time/                     |          |
# |    fps                    | 603      |
# |    iterations             | 5        |
# |    time_elapsed           | 16       |
# |    total_timesteps        | 10240    |
# | train/                    |          |
# |    explained_variance     | 0        |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00963  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 4        |
# |    policy_objective       | 0.00162  |
# |    value_loss             | 0.00033  |
# ----------------------------------------
# ----------------------------------------
# | time/                     |          |
# |    fps                    | 606      |
# |    iterations             | 6        |
# |    time_elapsed           | 20       |
# |    total_timesteps        | 12288    |
# | train/                    |          |
# |    explained_variance     | 0        |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00937  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 5        |
# |    policy_objective       | 0.00308  |
# |    value_loss             | 0.000205 |
# ----------------------------------------
# ----------------------------------------
# | time/                     |          |
# |    fps                    | 612      |
# |    iterations             | 7        |
# |    time_elapsed           | 23       |
# |    total_timesteps        | 14336    |
# | train/                    |          |
# |    explained_variance     | 0        |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00911  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 6        |
# |    policy_objective       | 0.00441  |
# |    value_loss             | 0.000151 |
# ----------------------------------------
# ----------------------------------------
# | time/                     |          |
# |    fps                    | 617      |
# |    iterations             | 8        |
# |    time_elapsed           | 26       |
# |    total_timesteps        | 16384    |
# | train/                    |          |
# |    explained_variance     | 0        |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00882  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 7        |
# |    policy_objective       | 0.00273  |
# |    value_loss             | 0.000117 |
# ----------------------------------------
# ----------------------------------------
# | time/                     |          |
# |    fps                    | 620      |
# |    iterations             | 9        |
# |    time_elapsed           | 29       |
# |    total_timesteps        | 18432    |
# | train/                    |          |
# |    explained_variance     | 0        |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00849  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 8        |
# |    policy_objective       | 0.00302  |
# |    value_loss             | 7.82e-05 |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 1.93e+04 |
# |    ep_rew_mean            | 0.49     |
# | time/                     |          |
# |    fps                    | 622      |
# |    iterations             | 10       |
# |    time_elapsed           | 32       |
# |    total_timesteps        | 20480    |
# | train/                    |          |
# |    explained_variance     | 0        |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00735  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 9        |
# |    policy_objective       | 0.00131  |
# |    value_loss             | 6.83e-05 |
# ----------------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 1.93e+04  |
# |    ep_rew_mean            | 0.49      |
# | time/                     |           |
# |    fps                    | 624       |
# |    iterations             | 11        |
# |    time_elapsed           | 36        |
# |    total_timesteps        | 22528     |
# | train/                    |           |
# |    explained_variance     | -1.19e-07 |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00846   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 10        |
# |    policy_objective       | 0.000351  |
# |    value_loss             | 0.000201  |
# -----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 1.93e+04 |
# |    ep_rew_mean            | 0.49     |
# | time/                     |          |
# |    fps                    | 624      |
# |    iterations             | 12       |
# |    time_elapsed           | 39       |
# |    total_timesteps        | 24576    |
# | train/                    |          |
# |    explained_variance     | 0        |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00738  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 11       |
# |    policy_objective       | 0.00153  |
# |    value_loss             | 4.11e-05 |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 1.93e+04 |
# |    ep_rew_mean            | 0.49     |
# | time/                     |          |
# |    fps                    | 621      |
# |    iterations             | 13       |
# |    time_elapsed           | 42       |
# |    total_timesteps        | 26624    |
# | train/                    |          |
# |    explained_variance     | 0        |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00715  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 12       |
# |    policy_objective       | 0.000688 |
# |    value_loss             | 3.45e-05 |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 1.93e+04 |
# |    ep_rew_mean            | 0.49     |
# | time/                     |          |
# |    fps                    | 622      |
# |    iterations             | 14       |
# |    time_elapsed           | 46       |
# |    total_timesteps        | 28672    |
# | train/                    |          |
# |    explained_variance     | 0        |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00696  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 13       |
# |    policy_objective       | 0.0019   |
# |    value_loss             | 3.73e-05 |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 1.93e+04 |
# |    ep_rew_mean            | 0.49     |
# | time/                     |          |
# |    fps                    | 620      |
# |    iterations             | 15       |
# |    time_elapsed           | 49       |
# |    total_timesteps        | 30720    |
# | train/                    |          |
# |    explained_variance     | 0        |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00897  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 14       |
# |    policy_objective       | 0.00106  |
# |    value_loss             | 2.26e-05 |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 1.93e+04 |
# |    ep_rew_mean            | 0.49     |
# | time/                     |          |
# |    fps                    | 616      |
# |    iterations             | 16       |
# |    time_elapsed           | 53       |
# |    total_timesteps        | 32768    |
# | train/                    |          |
# |    explained_variance     | 0        |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00699  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 15       |
# |    policy_objective       | 4.67e-05 |
# |    value_loss             | 2.36e-05 |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 1.93e+04 |
# |    ep_rew_mean            | 0.49     |
# | time/                     |          |
# |    fps                    | 613      |
# |    iterations             | 17       |
# |    time_elapsed           | 56       |
# |    total_timesteps        | 34816    |
# | train/                    |          |
# |    explained_variance     | 1.19e-07 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00683  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 16       |
# |    policy_objective       | 0.00041  |
# |    value_loss             | 2.57e-05 |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 1.93e+04 |
# |    ep_rew_mean            | 0.49     |
# | time/                     |          |
# |    fps                    | 614      |
# |    iterations             | 18       |
# |    time_elapsed           | 59       |
# |    total_timesteps        | 36864    |
# | train/                    |          |
# |    explained_variance     | 0        |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.0067   |
# |    learning_rate          | 0.001    |
# |    n_updates              | 17       |
# |    policy_objective       | 0.00101  |
# |    value_loss             | 1.77e-05 |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 1.93e+04 |
# |    ep_rew_mean            | 0.508    |
# | time/                     |          |
# |    fps                    | 614      |
# |    iterations             | 19       |
# |    time_elapsed           | 63       |
# |    total_timesteps        | 38912    |
# | train/                    |          |
# |    explained_variance     | 0        |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00657  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 18       |
# |    policy_objective       | 0.00151  |
# |    value_loss             | 1.39e-05 |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 1.93e+04 |
# |    ep_rew_mean            | 0.508    |
# | time/                     |          |
# |    fps                    | 616      |
# |    iterations             | 20       |
# |    time_elapsed           | 66       |
# |    total_timesteps        | 40960    |
# | train/                    |          |
# |    explained_variance     | 0        |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.0096   |
# |    learning_rate          | 0.001    |
# |    n_updates              | 19       |
# |    policy_objective       | 0.00415  |
# |    value_loss             | 3.63e-05 |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 1.93e+04 |
# |    ep_rew_mean            | 0.508    |
# | time/                     |          |
# |    fps                    | 618      |
# |    iterations             | 21       |
# |    time_elapsed           | 69       |
# |    total_timesteps        | 43008    |
# | train/                    |          |
# |    explained_variance     | 0        |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.0066   |
# |    learning_rate          | 0.001    |
# |    n_updates              | 20       |
# |    policy_objective       | 0.00134  |
# |    value_loss             | 9.04e-05 |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 1.93e+04 |
# |    ep_rew_mean            | 0.508    |
# | time/                     |          |
# |    fps                    | 619      |
# |    iterations             | 22       |
# |    time_elapsed           | 72       |
# |    total_timesteps        | 45056    |
# | train/                    |          |
# |    explained_variance     | 0        |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00955  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 21       |
# |    policy_objective       | 0.00124  |
# |    value_loss             | 2.55e-05 |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 1.93e+04 |
# |    ep_rew_mean            | 0.508    |
# | time/                     |          |
# |    fps                    | 621      |
# |    iterations             | 23       |
# |    time_elapsed           | 75       |
# |    total_timesteps        | 47104    |
# | train/                    |          |
# |    explained_variance     | 0        |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.0093   |
# |    learning_rate          | 0.001    |
# |    n_updates              | 22       |
# |    policy_objective       | 0.00119  |
# |    value_loss             | 2.66e-05 |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 1.93e+04 |
# |    ep_rew_mean            | 0.508    |
# | time/                     |          |
# |    fps                    | 622      |
# |    iterations             | 24       |
# |    time_elapsed           | 78       |
# |    total_timesteps        | 49152    |
# | train/                    |          |
# |    explained_variance     | 0        |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00678  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 23       |
# |    policy_objective       | 0.0013   |
# |    value_loss             | 2.37e-05 |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 1.93e+04 |
# |    ep_rew_mean            | 0.508    |
# | time/                     |          |
# |    fps                    | 623      |
# |    iterations             | 25       |
# |    time_elapsed           | 82       |
# |    total_timesteps        | 51200    |
# | train/                    |          |
# |    explained_variance     | 0        |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00665  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 24       |
# |    policy_objective       | 0.00239  |
# |    value_loss             | 3.96e-05 |
# ----------------------------------------
# 0.0009944243323289914 252.11562676821472
# 8076 4620 0

# %%
test_env=train_env(all_test,price_test,vol_test,sharpe_test,maxDiv_test)
episodes = 1
TRPOrewardList=[]
TRPOunweightedRewardList=[]
TRPOsharpeRewardList=[]
TRPOmarkRewardList=[]
test_env.reset()
obvs=test_env.reset()
done=False
while done == False:
  action,_states=TRPOmodel.predict(obvs)
  obvs,rewards,done,info=test_env.step(action)
  #print('NW',test_env.net_worth)
  TRPOrewardList.append(test_env.net_worth)
  TRPOunweightedRewardList.append(test_env.even_net_worth)
  TRPOsharpeRewardList.append(test_env.sharpe_net_worth)
  TRPOmarkRewardList.append(test_env.mark_net_worth)

# %%
plt.figure(figsize=(10,10))
plt.plot(TRPOrewardList,linewidth=4, color='black', label='Robot Return')
plt.plot(TRPOunweightedRewardList,linewidth=4,color='orange',label='Baseline Portfolio')
plt.plot(TRPOsharpeRewardList,linewidth=1,color='blue',label='Sharpe',linestyle='dashed')
plt.plot(TRPOmarkRewardList,linewidth=1,color='purple',label='Max Diverse',linestyle='dashed')
plt.title('TRPO')
plt.legend()
print(TRPOrewardList[-1]/TRPOunweightedRewardList[-1])
print(TRPOrewardList[-1]/TRPOsharpeRewardList[-1])
print(TRPOrewardList[-1])
# Out:
# 1.114991652590137
# 0.9863216488594397
# 160.37185222777717

# %%
test_env=train_env(all_test,price_test,vol_test,sharpe_test,maxDiv_test)
episodes = 1
TRPOrewardList2=[]
TRPOunweightedRewardList2=[]
TRPOsharpeRewardList2=[]
TRPOmarkRewardList2=[]
test_env.reset()
obvs=test_env.reset()
done=False
while done == False:
  action,_states=TRPOmodel.predict(obvs)
  obvs,rewards,done,info=test_env.step(action)
  #print('NW',test_env.net_worth)
  TRPOrewardList2.append(test_env.net_worth)
  TRPOunweightedRewardList2.append(test_env.even_net_worth)
  TRPOsharpeRewardList2.append(test_env.sharpe_net_worth)
  TRPOmarkRewardList2.append(test_env.mark_net_worth)

# %%
plt.figure(figsize=(10,10))
plt.plot(TRPOrewardList2,linewidth=4, color='black', label='Robot Return')
plt.plot(TRPOunweightedRewardList2,linewidth=4,color='orange',label='Baseline Portfolio')
plt.plot(TRPOsharpeRewardList2,linewidth=1,color='blue',label='Sharpe',linestyle='dashed')
plt.plot(TRPOmarkRewardList2,linewidth=1,color='purple',label='Max Diverse',linestyle='dashed')
plt.title('TRPO')
plt.legend()
print(TRPOrewardList2[-1]/TRPOunweightedRewardList2[-1])
print(TRPOrewardList2[-1]/TRPOsharpeRewardList2[-1])
print(TRPOrewardList2[-1])
# Out:
# 1.1094496514204975
# 0.9814191944608602
# 159.57473326230422

# %%
test_env=train_env(all_test,price_test,vol_test,sharpe_test,maxDiv_test)
episodes = 1
TRPOrewardList3=[]
TRPOunweightedRewardList3=[]
TRPOsharpeRewardList3=[]
TRPOmarkRewardList3=[]
test_env.reset()
obvs=test_env.reset()
done=False
while done == False:
  action,_states=TRPOmodel.predict(obvs)
  obvs,rewards,done,info=test_env.step(action)
  TRPOrewardList3.append(test_env.net_worth)
  TRPOunweightedRewardList3.append(test_env.even_net_worth)
  TRPOsharpeRewardList3.append(test_env.sharpe_net_worth)
  TRPOmarkRewardList3.append(test_env.mark_net_worth)

# %%
plt.figure(figsize=(10,10))
plt.plot(TRPOrewardList3,linewidth=4, color='black', label='Robot Return')
plt.plot(TRPOunweightedRewardList3,linewidth=4,color='orange',label='Baseline Portfolio')
plt.plot(TRPOsharpeRewardList3,linewidth=1,color='blue',label='Sharpe',linestyle='dashed')
plt.plot(TRPOmarkRewardList3,linewidth=1,color='purple',label='Max Diverse',linestyle='dashed')
plt.title('TRPO')
plt.legend()
print(TRPOrewardList3[-1]/TRPOunweightedRewardList3[-1])
print(TRPOrewardList3[-1]/TRPOsharpeRewardList3[-1])
print(TRPOrewardList3[-1])
# Out:
# 1.2130961347693605
# 1.0731048766968256
# 174.4824489146498

# %%
test_env=train_env(all_test,price_test,vol_test,sharpe_test,maxDiv_test)
episodes = 1
TRPOrewardList4=[]
TRPOunweightedRewardList4=[]
TRPOsharpeRewardList4=[]
TRPOmarkRewardList4=[]
test_env.reset()
obvs=test_env.reset()
done=False
while done == False:
  action,_states=TRPOmodel.predict(obvs)
  obvs,rewards,done,info=test_env.step(action)
  TRPOrewardList4.append(test_env.net_worth)
  TRPOunweightedRewardList4.append(test_env.even_net_worth)
  TRPOsharpeRewardList4.append(test_env.sharpe_net_worth)
  TRPOmarkRewardList4.append(test_env.mark_net_worth)

# %%
plt.figure(figsize=(10,10))
plt.plot(TRPOrewardList4,linewidth=4, color='black', label='Robot Return')
plt.plot(TRPOunweightedRewardList4,linewidth=4,color='orange',label='Baseline Portfolio')
plt.plot(TRPOsharpeRewardList4,linewidth=1,color='blue',label='Sharpe',linestyle='dashed')
plt.plot(TRPOmarkRewardList4,linewidth=1,color='purple',label='Max Diverse',linestyle='dashed')
plt.title('TRPO')
plt.legend()
print(TRPOrewardList4[-1]/TRPOunweightedRewardList4[-1])
print(TRPOrewardList4[-1]/TRPOsharpeRewardList4[-1])
print(TRPOrewardList4[-1])
# Out:
# 1.0552066357618328
# 0.9334358212048552
# 151.77283369526052

# %%
test_env=train_env(all_test,price_test,vol_test,sharpe_test,maxDiv_test)
episodes = 1
TRPOrewardList5=[]
TRPOunweightedRewardList5=[]
TRPOsharpeRewardList5=[]
TRPOmarkRewardList5=[]
test_env.reset()
obvs=test_env.reset()
done=False
while done == False:
  action,_states=TRPOmodel.predict(obvs)
  obvs,rewards,done,info=test_env.step(action)
  #print('NW',test_env.net_worth)
  TRPOrewardList5.append(test_env.net_worth)
  TRPOunweightedRewardList5.append(test_env.even_net_worth)
  TRPOsharpeRewardList5.append(test_env.sharpe_net_worth)
  TRPOmarkRewardList5.append(test_env.mark_net_worth)

# %%
plt.figure(figsize=(10,10))
plt.plot(TRPOrewardList5,linewidth=4, color='black', label='Robot Return')
plt.plot(TRPOunweightedRewardList5,linewidth=4,color='orange',label='Baseline Portfolio')
plt.plot(TRPOsharpeRewardList5,linewidth=1,color='blue',label='Sharpe',linestyle='dashed')
plt.plot(TRPOmarkRewardList5,linewidth=1,color='purple',label='Max Diverse',linestyle='dashed')
plt.title('TRPO')
plt.legend()
print(TRPOrewardList5[-1]/TRPOunweightedRewardList5[-1])
print(TRPOrewardList5[-1]/TRPOsharpeRewardList5[-1])
print(TRPOrewardList5[-1])
# Out:
# 1.1477635245979532
# 1.0153116478068505
# 165.08550708129658

# %% [markdown]
# # Results and Discussion
# A common problem across all model types seems to be that they tend to cling to one action choice or the other as soon as they begin to get consistent positive rewards from it.  This results in many test graphs where the model performance tracks closely to one of the two portfolio metrics.  This could probably be dealt with by increasing the amount of forced error or randomness in the model's choices.
#
# All models performed well compared to the baseline and the SP500 over an equivalent timeframe.  The true desired outcome, however, is to have the model outperform both portfolio metrics by combining knowledge from each technique and learning how to situationally apply the optimal action - it is not impressive to build a complex model that can be outperformed by simpler methods.
#
# TRPO seems to consistently outperform both portfolio metrics more than the others.  PPO and A2C seem more inconsistent.  The specific TRPO iteration below outperforms the baseline by 21.3% and, more significantly, outperforms the Sharpe portfolio metric by 7.3%.  I consider this a successful outcome within the context of this project.
#
# Further steps are to experiment with different portfolio assets, tweak the model hyperparameters to encourage more exploration, and expand the amount and diversity of market data tested on.
#
# For the purposes of my stakeholder, the potential ability to generate excess market returns of 20% or more is hugely significant. If the results of the model provided below can be consistently replicated, this would outperform many traditional active strategies as well.

# %%
plt.figure(figsize=(20,7))
plt.plot(TRPOrewardList3,linewidth=4, color='black', label='Robot Return')
plt.plot(TRPOunweightedRewardList3,linewidth=4,color='orange',label='Baseline Portfolio')
plt.plot(TRPOsharpeRewardList3,linewidth=1,color='blue',label='Sharpe')
plt.plot(TRPOmarkRewardList3,linewidth=1,color='purple',label='Max Diverse')
plt.title('TRPO')
plt.legend()
print(TRPOrewardList3[-1]/TRPOunweightedRewardList3[-1])
print(TRPOrewardList3[-1]/TRPOsharpeRewardList3[-1])
# Out:
# 1.2130961347693605
# 1.0731048766968256

# %% [markdown]
# # Conclusion
#
# This notebook has demonstrated the established portfolio optimization strategies can be successfully used in conjunction with reinforcement learning to generate returns outperforming both the base optimization strategies and a base portfolio.
#
# The next steps would be to add more real-world factors such as transaction costs and train the models on more data to verify replicability across market environments.
